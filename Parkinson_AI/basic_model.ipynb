# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from sklearn.model_selection import train_test_split
from os import listdir, makedirs
import time

# %%
def df_to_dataset(dataframe, shuffle=True, batch_size=32):
    dataframe = dataframe.copy()
    labels = dataframe.pop('targetValue')
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe))
    ds = ds.batch(batch_size)
    ds = ds.prefetch(batch_size)
    return ds

def get_normalization_layer(name, dataset):
    # Create a Normalization layer for our feature.
    normalizer = preprocessing.Normalization()
    # Prepare a Dataset that only yields our feature.
    feature_ds = dataset.map(lambda x, y: x[name])
    # Learn the statistics of the data.
    normalizer.adapt(feature_ds)
    return normalizer

# %%
def data_model(path, save_path, save_name_start = 'train', whole_files = False, iter_num = 5, epoch_num =20):
    """
    Function that creates datasets out of csv files and normalizes them using Keras layer preprocessing. Then a model is 
    created     and trained multiple times. Then it's metrics are saved and their summary is printed in the console.
    
    Parameters:
    path - filepath of the csv document with features
    save_path - directory where model metrics will be saved
    save_name_start - beginning of each saved file
    whole_files - whether the model is trained on whole or split files
    iter_num - number of model training iterations
    iter_num - number of epochs
    
    Returns:
    df - Padnas DataFrame with best metrics from each cycle
    summary - model summary
    """
    try:
        makedirs(save_path)
    except:
        pass
    save_path = save_path+save_name_start
    file = path
    df = pd.read_csv(file)
    df.drop('Unnamed: 0', axis=1, inplace = True)
    if not whole_files:
        test_pd = df[0:10]
        test_hc = df[len(df)-10:len(df)]
        test = test_pd.append(test_hc)
        a = list(np.linspace(0,9,10).astype(int))
        df.drop(a, inplace=True)
        a = list(np.linspace(len(df)-10,len(df),10).astype(int))
        df.drop(a,inplace=True)
    train, val = train_test_split(df, test_size=0.3, random_state=55)
    batch_size = 20
    train_ds = df_to_dataset(train, batch_size=batch_size)
    column_list = train.columns[0:-1]
    all_inputs = []
    encoded_features = []
    count = 0
    for header in column_list:
        count += 1
        print('Processed %d column out of %d' % (count, len(column_list)), end="\r", flush=True)
        numeric_col = tf.keras.Input(shape=(1,), name=header)
        normalization_layer = get_normalization_layer(header, train_ds)
        encoded_numeric_col = normalization_layer(numeric_col)
        all_inputs.append(numeric_col)
        encoded_features.append(encoded_numeric_col)
        
    print("")
    # Build model
    all_features = tf.keras.layers.concatenate(encoded_features)
    x = tf.keras.layers.Dense(32, activation="relu")(all_features)
    x = tf.keras.layers.Dropout(0.4)(x)
    output = tf.keras.layers.Dense(1)(x)
    val_ds = df_to_dataset(val, shuffle=False, batch_size=batch_size)
    if not whole_files:
        test_ds = df_to_dataset(test, shuffle=False, batch_size=batch_size)
    best_loss = []
    best_acc = []
    best_loss_val = []
    best_acc_val = []
    if not whole_files:
        test_acc = []
        test_loss = []
    iterator = 0
    while iterator<iter_num:
        iterator += 1
        print('Training cycle %d out of %d' % (iterator, iter_num), end="\r", flush=True)
        model = tf.keras.Model(all_inputs, output)
        model.compile(optimizer='adam',
                      loss=tf.keras.losses.BinaryCrossentropy(),
                      metrics=["accuracy"])
        model.fit(train_ds, epochs=epoch_num, validation_data=val_ds, verbose=0)
        df = pd.DataFrame()
        for part in ['loss', 'accuracy', 'val_loss', 'val_accuracy']: 
            df[part] = model.history.history[part]
        df.index.names = ['Epoch']
        df.to_csv(save_path+'_training'+str(iterator)+'.csv')
        
        # Save best values
        best_loss.append(max(model.history.history['loss']))
        best_acc.append(max(model.history.history['accuracy']))
        best_loss_val.append(max(model.history.history['val_loss']))
        best_acc_val.append(max(model.history.history['val_accuracy']))
        if not whole_files:
            eval_metrics = model.evaluate(train_ds, verbose=0)
            test_acc.append(eval_metrics[1])
            test_loss.append(eval_metrics[0])
        summary = model.summary # Every model is the same so the summary can be called post training loop
        del model
    print("")
    # Post training
    df = pd.DataFrame()
    df['Best_Loss'] = best_loss
    df['Best_Acc'] = best_acc
    df['Best_Loss_Val'] = best_loss_val
    df['Best_Acc_Val'] = best_acc_val
    if not whole_files:
        df['Test_Loss'] = test_loss
        df['Test_Acc'] = test_acc
    df.index.names = ['Model_Num']
    df.to_csv(save_path+'_best'+'.csv')
    return df, summary

# %%
start_time = time.time()
df, summary = data_model('./csvs/GeMAPS/ReadText_GeMAPSv01b.csv', './train_outputs/ReadText_GeMAPSv01b/',
                         'Metrics', iter_num=3)
print('Elapsed time: ' , time.time() - start_time)
display(df)
# Out:
# Processed 62 column out of 62
# Training cycle 3 out of 3
# Elapsed time:  14.01936936378479
#            Best_Loss  Best_Acc  Best_Loss_Val  Best_Acc_Val  Test_Loss  \
# Model_Num
# 0           6.103929  0.713043       3.850484          0.80   2.588799
# 1           3.491644  0.843478       2.331122          0.78   0.442858
# 2           1.975386  0.886957       1.223402          0.86   0.206845
#
#            Test_Acc
# Model_Num
# 0          0.704348
# 1          0.886957
# 2          0.956522

# %%
print(summary()) # It's in new cell because of the summary's size
# Out:
# Model: "functional_25"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# F0semitoneFrom27.5Hz_sma3nz_ame [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_pct [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile20.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile50.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile80.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_pctlrange0-2 (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanRisingSlope ( [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevRisingSlope [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanFallingSlope  [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevFallingSlop [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_amean (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_stddevNorm (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_amean ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_stddevN [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioUV_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexUV_sma3nz_amean  [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV0-500_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV500-1500_sma3nz_amean (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudnessPeaksPerSec (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# VoicedSegmentsPerSec (InputLaye [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanVoicedSegmentLengthSec (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevVoicedSegmentLengthSec (I [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanUnvoicedSegmentLength (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevUnvoicedSegmentLength (In [(None, 1)]          0
# __________________________________________________________________________________________________
# normalization_160 (Normalizatio (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_amean
# __________________________________________________________________________________________________
# normalization_161 (Normalizatio (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_162 (Normalizatio (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_163 (Normalizatio (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_164 (Normalizatio (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_165 (Normalizatio (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_pctlr
# __________________________________________________________________________________________________
# normalization_166 (Normalizatio (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanR
# __________________________________________________________________________________________________
# normalization_167 (Normalizatio (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_168 (Normalizatio (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanF
# __________________________________________________________________________________________________
# normalization_169 (Normalizatio (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_170 (Normalizatio (None, 1)            3           loudness_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_171 (Normalizatio (None, 1)            3           loudness_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_172 (Normalizatio (None, 1)            3           loudness_sma3_percentile20.0[0][0
# __________________________________________________________________________________________________
# normalization_173 (Normalizatio (None, 1)            3           loudness_sma3_percentile50.0[0][0
# __________________________________________________________________________________________________
# normalization_174 (Normalizatio (None, 1)            3           loudness_sma3_percentile80.0[0][0
# __________________________________________________________________________________________________
# normalization_175 (Normalizatio (None, 1)            3           loudness_sma3_pctlrange0-2[0][0]
# __________________________________________________________________________________________________
# normalization_176 (Normalizatio (None, 1)            3           loudness_sma3_meanRisingSlope[0][
# __________________________________________________________________________________________________
# normalization_177 (Normalizatio (None, 1)            3           loudness_sma3_stddevRisingSlope[0
# __________________________________________________________________________________________________
# normalization_178 (Normalizatio (None, 1)            3           loudness_sma3_meanFallingSlope[0]
# __________________________________________________________________________________________________
# normalization_179 (Normalizatio (None, 1)            3           loudness_sma3_stddevFallingSlope[
# __________________________________________________________________________________________________
# normalization_180 (Normalizatio (None, 1)            3           jitterLocal_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_181 (Normalizatio (None, 1)            3           jitterLocal_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_182 (Normalizatio (None, 1)            3           shimmerLocaldB_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_183 (Normalizatio (None, 1)            3           shimmerLocaldB_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_184 (Normalizatio (None, 1)            3           HNRdBACF_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_185 (Normalizatio (None, 1)            3           HNRdBACF_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_186 (Normalizatio (None, 1)            3           logRelF0-H1-H2_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_187 (Normalizatio (None, 1)            3           logRelF0-H1-H2_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_188 (Normalizatio (None, 1)            3           logRelF0-H1-A3_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_189 (Normalizatio (None, 1)            3           logRelF0-H1-A3_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_190 (Normalizatio (None, 1)            3           F1frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_191 (Normalizatio (None, 1)            3           F1frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_192 (Normalizatio (None, 1)            3           F1bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_193 (Normalizatio (None, 1)            3           F1bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_194 (Normalizatio (None, 1)            3           F1amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_195 (Normalizatio (None, 1)            3           F1amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_196 (Normalizatio (None, 1)            3           F2frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_197 (Normalizatio (None, 1)            3           F2frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_198 (Normalizatio (None, 1)            3           F2amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_199 (Normalizatio (None, 1)            3           F2amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_200 (Normalizatio (None, 1)            3           F3frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_201 (Normalizatio (None, 1)            3           F3frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_202 (Normalizatio (None, 1)            3           F3amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_203 (Normalizatio (None, 1)            3           F3amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_204 (Normalizatio (None, 1)            3           alphaRatioV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_205 (Normalizatio (None, 1)            3           alphaRatioV_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_206 (Normalizatio (None, 1)            3           hammarbergIndexV_sma3nz_amean[0][
# __________________________________________________________________________________________________
# normalization_207 (Normalizatio (None, 1)            3           hammarbergIndexV_sma3nz_stddevNor
# __________________________________________________________________________________________________
# normalization_208 (Normalizatio (None, 1)            3           slopeV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_209 (Normalizatio (None, 1)            3           slopeV0-500_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_210 (Normalizatio (None, 1)            3           slopeV500-1500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_211 (Normalizatio (None, 1)            3           slopeV500-1500_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_212 (Normalizatio (None, 1)            3           alphaRatioUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_213 (Normalizatio (None, 1)            3           hammarbergIndexUV_sma3nz_amean[0]
# __________________________________________________________________________________________________
# normalization_214 (Normalizatio (None, 1)            3           slopeUV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_215 (Normalizatio (None, 1)            3           slopeUV500-1500_sma3nz_amean[0][0
# __________________________________________________________________________________________________
# normalization_216 (Normalizatio (None, 1)            3           loudnessPeaksPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_217 (Normalizatio (None, 1)            3           VoicedSegmentsPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_218 (Normalizatio (None, 1)            3           MeanVoicedSegmentLengthSec[0][0]
# __________________________________________________________________________________________________
# normalization_219 (Normalizatio (None, 1)            3           StddevVoicedSegmentLengthSec[0][0
# __________________________________________________________________________________________________
# normalization_220 (Normalizatio (None, 1)            3           MeanUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_221 (Normalizatio (None, 1)            3           StddevUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 62)           0           normalization_160[0][0]
#                                                                  normalization_161[0][0]
#                                                                  normalization_162[0][0]
#                                                                  normalization_163[0][0]
#                                                                  normalization_164[0][0]
#                                                                  normalization_165[0][0]
#                                                                  normalization_166[0][0]
#                                                                  normalization_167[0][0]
#                                                                  normalization_168[0][0]
#                                                                  normalization_169[0][0]
#                                                                  normalization_170[0][0]
#                                                                  normalization_171[0][0]
#                                                                  normalization_172[0][0]
#                                                                  normalization_173[0][0]
#                                                                  normalization_174[0][0]
#                                                                  normalization_175[0][0]
#                                                                  normalization_176[0][0]
#                                                                  normalization_177[0][0]
#                                                                  normalization_178[0][0]
#                                                                  normalization_179[0][0]
#                                                                  normalization_180[0][0]
#                                                                  normalization_181[0][0]
#                                                                  normalization_182[0][0]
#                                                                  normalization_183[0][0]
#                                                                  normalization_184[0][0]
#                                                                  normalization_185[0][0]
#                                                                  normalization_186[0][0]
#                                                                  normalization_187[0][0]
#                                                                  normalization_188[0][0]
#                                                                  normalization_189[0][0]
#                                                                  normalization_190[0][0]
#                                                                  normalization_191[0][0]
#                                                                  normalization_192[0][0]
#                                                                  normalization_193[0][0]
#                                                                  normalization_194[0][0]
#                                                                  normalization_195[0][0]
#                                                                  normalization_196[0][0]
#                                                                  normalization_197[0][0]
#                                                                  normalization_198[0][0]
#                                                                  normalization_199[0][0]
#                                                                  normalization_200[0][0]
#                                                                  normalization_201[0][0]
#                                                                  normalization_202[0][0]
#                                                                  normalization_203[0][0]
#                                                                  normalization_204[0][0]
#                                                                  normalization_205[0][0]
#                                                                  normalization_206[0][0]
#                                                                  normalization_207[0][0]
#                                                                  normalization_208[0][0]
#                                                                  normalization_209[0][0]
#                                                                  normalization_210[0][0]
#                                                                  normalization_211[0][0]
#                                                                  normalization_212[0][0]
#                                                                  normalization_213[0][0]
#                                                                  normalization_214[0][0]
#                                                                  normalization_215[0][0]
#                                                                  normalization_216[0][0]
#                                                                  normalization_217[0][0]
#                                                                  normalization_218[0][0]
#                                                                  normalization_219[0][0]
#                                                                  normalization_220[0][0]
#                                                                  normalization_221[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 32)           2016        concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            33          dropout_2[0][0]
# ==================================================================================================
# Total params: 2,235
# Trainable params: 2,049
# Non-trainable params: 186
# __________________________________________________________________________________________________
# None

# %%
# Compare set works much slower and there's something wrong with some names in it
# Returns "ValueError: 'audSpec_Rfilt_sma[0]_range' is not a valid scope name" error at 249 column
# start_time = time.time()
# df, summary = data_model('./csvs/ReadText_ComParE2016.csv', './csvs/train_outputs/ReadText_Compare/',
#                          'Metrics', iter_num=3)
# print('Elapsed time: ' , time.time() - start_time)
# display(df)
# Out:
# Processed 249 column out of 6373
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-be4fb08cd313> in <module>
#       1 start_time = time.time()
# ----> 2 df, summary = data_model('./csvs/ReadText_ComParE2016.csv', './csvs/train_outputs/ReadText_Compare/',
#       3                          'Metrics', iter_num=3)
#       4 print('Elapsed time: ' , time.time() - start_time)
#       5 display(df)
#
# <ipython-input-20-1b75384f552e> in data_model(path, save_path, save_name_start, whole_files, iter_num, epoch_num)
#      40         count += 1
#      41         print('Processed %d column out of %d' % (count, len(column_list)), end="\r", flush=True)
# ---> 42         numeric_col = tf.keras.Input(shape=(1,), name=header)
#      43         normalization_layer = get_normalization_layer(header, train_ds)
#      44         encoded_numeric_col = normalization_layer(numeric_col)
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\input_layer.py in Input(shape, batch_size, name, dtype, sparse, tensor, ragged, **kwargs)
#     309     input_layer_config.update(
#     310         {'batch_size': batch_size, 'input_shape': shape})
# --> 311   input_layer = InputLayer(**input_layer_config)
#     312
#     313   # Return tensor including `_keras_history`.
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\input_layer.py in __init__(self, input_shape, batch_size, dtype, input_tensor, sparse, name, ragged, **kwargs)
#     153       graph = backend.get_graph()
#     154       with graph.as_default():
# --> 155         input_tensor = backend.placeholder(
#     156             shape=batch_input_shape,
#     157             dtype=dtype,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\backend.py in placeholder(shape, ndim, dtype, sparse, name, ragged)
#    1221                                expand_composites=True)
#    1222       else:
# -> 1223         x = array_ops.placeholder(dtype, shape=shape, name=name)
#    1224
#    1225   if context.executing_eagerly():
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\array_ops.py in placeholder(dtype, shape, name)
#    3098                        "eager execution.")
#    3099
# -> 3100   return gen_array_ops.placeholder(dtype=dtype, shape=shape, name=name)
#    3101
#    3102
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\gen_array_ops.py in placeholder(dtype, shape, name)
#    6806     shape = None
#    6807   shape = _execute.make_shape(shape, "shape")
# -> 6808   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    6809         "Placeholder", dtype=dtype, shape=shape, name=name)
#    6810   _result = _outputs[:]
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     351   inputs = []
#     352   input_types = []
# --> 353   with g.as_default(), ops.name_scope(name) as scope:
#     354
#     355     # Perform input type inference
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\ops.py in __enter__(self)
#    6490     try:
#    6491       self._name_scope = g.name_scope(self._name)
# -> 6492       return self._name_scope.__enter__()
#    6493     except:
#    6494       if self._g_manager is not None:
#
# ~\anaconda3\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\ops.py in name_scope(self, name)
#    4188         # op name regex, which constrains the initial character.
#    4189         if not _VALID_OP_NAME_REGEX.match(name):
# -> 4190           raise ValueError("'%s' is not a valid scope name" % name)
#    4191     old_stack = self._name_stack
#    4192     if not name:  # Both for name=None and name="" we re-set to empty scope.
#
# ValueError: 'audSpec_Rfilt_sma[0]_range' is not a valid scope name

# %%
# Training models for GeMAPS and eGeMAPS csv datasets
start_time_full = time.time()
for directory in ['./csvs/GeMAPS/','./csvs/eGeMAPS/']:
    file_list = listdir(directory)
    print('File list:')
    print(file_list)
    print('Model training: ')
    for file in file_list:
        a = file[0:-4]
        print('')
        print('---------------------------------------------------------------------------------------------------------------')
        print('')
        print('\t \t \t Processing file ', a)
        print('')
        print('---------------------------------------------------------------------------------------------------------------')
        print('')
        start_time = time.time()
        df, summary = data_model(directory+file, './train_outputs/'+a+'/', 'Metrics')
        print('Elapsed time: ' , time.time() - start_time)

print('Full elapsed time: ' , time.time() - start_time_full)
# Out:
# File list:
# ['ReadText_GeMAPSv01b.csv', 'SpontaneousDialogue_GeMAPSv01b.csv']
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing file  ReadText_GeMAPSv01b
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 62 column out of 62
# Training cycle 5 out of 5
# Elapsed time:  31.18152379989624
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing file  SpontaneousDialogue_GeMAPSv01b
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 62 column out of 62
# Training cycle 5 out of 5
# Elapsed time:  33.37437415122986
# File list:
# ['ReadText_eGeMAPSv01b.csv', 'SpontaneousDialogue_eGeMAPSv01b.csv']
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing file  ReadText_eGeMAPSv01b
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 5 out of 5
# Elapsed time:  45.66367769241333
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing file  SpontaneousDialogue_eGeMAPSv01b
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 5 out of 5
# Elapsed time:  46.053789138793945
# Full elapsed time:  156.28074431419373
