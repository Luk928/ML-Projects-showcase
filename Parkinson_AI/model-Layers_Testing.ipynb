# %% [markdown]
# Contents:
# * [in > x > out](#id1)
# * [in > x > x > out](#id2)
# * [in > x > x/2 > out](#id3)
# * [in > x > x > x > out](#id4)
# * [in > x > x > x/2 > out](#id5)
# * [in > x > x/2 > x/2 > out](#id6)
# * [in > x > x/2 > x/4 > out](#id7)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from sklearn.model_selection import train_test_split
from os import listdir, makedirs
from sklearn.model_selection import KFold
import time
import random

# %%
def df_to_dataset(dataframe, shuffle=True, batch_size=32):
    dataframe = dataframe.copy()
    labels = dataframe.pop('targetValue')
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe))
    ds = ds.batch(batch_size)
    ds = ds.prefetch(batch_size)
    return ds

def get_normalization_layer(name, dataset):
    # Create a Normalization layer for our feature.
    normalizer = preprocessing.Normalization()
    # Prepare a Dataset that only yields our feature.
    feature_ds = dataset.map(lambda x, y: x[name])
    # Learn the statistics of the data.
    normalizer.adapt(feature_ds)
    return normalizer

def load_subsample_data(sample_array, subsample_array):
    """
    # %author Łukasz Ozimek
    Function to use arrays of sample numbers to load in data of subsample audio features.
    
    Parameter:
    sample_array - array of sample numbers
    subsample_array - array of subsample data
    
    Returns:
    final_array - array of subsample data for selected samples
    """
    final_array = np.zeros(shape=(int(len(sample_array)*5),len(subsample_array.columns)))
    idx = 0
    for i in sample_array:
        num = i*5
        for n in range(0,5):
            final_array[idx]=subsample_array[num+n:num+n+1]
            idx+=1
    return final_array

# %% [markdown]
# <a id='id1'></a>

# %%
def data_model(path, save_path, save_name_start = 'train', iter_num = 5, epoch_num =20, neurons = 32):
    """
    Function that creates datasets out of csv files and normalizes them using Keras layer preprocessing. Then a model is 
    created     and trained multiple times. Then it's metrics are saved and their summary is printed in the console.
    
    Parameters:
    path - filepath of the csv document with features
    save_path - directory where model metrics will be saved
    save_name_start - beginning of each saved file
    iter_num - number of Kfold splits
    epoch_num - number of epochs
    neurons - number of neurons on first dense layer
    
    Returns:
    df - Padnas DataFrame with best metrics from each cycle
    summary - model summary
    """
    try:
        makedirs(save_path)
    except:
        pass
    save_path = save_path+save_name_start
    file = path
    df = pd.read_csv(file)
    df.drop('Unnamed: 0', axis=1, inplace = True)
    base = list(range(0,int(len(df)/5))) #array of numbers equal to number of whole samples
    
    # Defining list to store best values
    best_loss = []
    best_acc = []
    best_loss_val = []
    best_acc_val = []
    batch_size = 20
    iterator = 0
    kfold = KFold(n_splits=iter_num, shuffle=True)
    
    for train_base, val_base in kfold.split(base):
        train = pd.DataFrame(load_subsample_data(train_base, df),columns=df.columns)
        val = pd.DataFrame(load_subsample_data(val_base, df),columns=df.columns)
        train_ds = df_to_dataset(train, batch_size=batch_size)
        column_list = train.columns[0:-1]
        all_inputs = []
        encoded_features = []
        count = 0
        for header in column_list:
            count += 1
            print('Processed %d column out of %d' % (count, len(column_list)), end="\r", flush=True)
            numeric_col = tf.keras.Input(shape=(1,), name=header)
            normalization_layer = get_normalization_layer(header, train_ds)
            encoded_numeric_col = normalization_layer(numeric_col)
            all_inputs.append(numeric_col)
            encoded_features.append(encoded_numeric_col)

        print("")
        # Build model
        all_features = tf.keras.layers.concatenate(encoded_features)
        x = tf.keras.layers.Dense(neurons, activation="relu")(all_features)
        x = tf.keras.layers.Dropout(0.4)(x)
        output = tf.keras.layers.Dense(1)(x)
        val_ds = df_to_dataset(val, shuffle=False, batch_size=batch_size)
        iterator += 1
        print('Training cycle %d out of %d' % (iterator, iter_num), end="\r", flush=True)
        model = tf.keras.Model(all_inputs, output)
        model.compile(optimizer='adam',
                      loss=tf.keras.losses.BinaryCrossentropy(),
                      metrics=["accuracy"])
        model.fit(train_ds, epochs=epoch_num, validation_data=val_ds, verbose=0)
        df2 = pd.DataFrame()
        for part in ['loss', 'accuracy', 'val_loss', 'val_accuracy']: 
            df2[part] = model.history.history[part]
        df2.index.names = ['Epoch']
        df2.to_csv(save_path+'_training'+str(iterator)+'.csv')

        # Save best values
        best_loss.append(max(model.history.history['loss']))
        best_acc.append(max(model.history.history['accuracy']))
        best_loss_val.append(max(model.history.history['val_loss']))
        best_acc_val.append(max(model.history.history['val_accuracy']))
        print("")
    
    # Post training
    summary = model.summary # Every model is the same so the summary can be called post training loop
    df = pd.DataFrame()
    df['Best_Loss'] = best_loss
    df['Best_Acc'] = best_acc
    df['Best_Loss_Val'] = best_loss_val
    df['Best_Acc_Val'] = best_acc_val
    df.index.names = ['Model_Num']
    df.to_csv(save_path+'_best'+'.csv')
    return df, summary

# %%
# Training models for architecture 1
start_time_full = time.time()
for number in [32, 64, 128]:
    print('Model training: ')
    print('')
    print('---------------------------------------------------------------------------------------------------------------')
    print('')
    print('\t \t \t Processing layers ', str(number))
    print('')
    print('---------------------------------------------------------------------------------------------------------------')
    print('')
    start_time = time.time()
    df, summary = data_model('./csvs/eGeMAPS/ReadText_eGeMAPSv01b.csv',
                             './layer_test_train_outputs/id1/'+str(number)+'/', 
                             'Id1', iter_num=8, epoch_num=100, neurons=number)
    print('Elapsed time: ' , time.time() - start_time)

print('Full elapsed time: ' , time.time() - start_time_full)
print(summary())
# Out:
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  32
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  139.51635646820068
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  64
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  150.18824219703674
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  128
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  144.3904676437378
# Full elapsed time:  434.0950663089752
# Model: "functional_47"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# F0semitoneFrom27.5Hz_sma3nz_ame [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_pct [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile20.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile50.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile80.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_pctlrange0-2 (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanRisingSlope ( [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevRisingSlope [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanFallingSlope  [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevFallingSlop [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFlux_sma3_amean (InputL [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFlux_sma3_stddevNorm (I [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_amean (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_stddevNorm (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_amean ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_stddevN [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxV_sma3nz_amean (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxV_sma3nz_stddevNorm [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioUV_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexUV_sma3nz_amean  [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV0-500_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV500-1500_sma3nz_amean (I [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxUV_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# loudnessPeaksPerSec (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# VoicedSegmentsPerSec (InputLaye [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanVoicedSegmentLengthSec (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevVoicedSegmentLengthSec (I [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanUnvoicedSegmentLength (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevUnvoicedSegmentLength (In [(None, 1)]          0
# __________________________________________________________________________________________________
# equivalentSoundLevel_dBp (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# normalization_2024 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_amean
# __________________________________________________________________________________________________
# normalization_2025 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_2026 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_2027 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_2028 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_2029 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_pctlr
# __________________________________________________________________________________________________
# normalization_2030 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanR
# __________________________________________________________________________________________________
# normalization_2031 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_2032 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanF
# __________________________________________________________________________________________________
# normalization_2033 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_2034 (Normalizati (None, 1)            3           loudness_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2035 (Normalizati (None, 1)            3           loudness_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_2036 (Normalizati (None, 1)            3           loudness_sma3_percentile20.0[0][0
# __________________________________________________________________________________________________
# normalization_2037 (Normalizati (None, 1)            3           loudness_sma3_percentile50.0[0][0
# __________________________________________________________________________________________________
# normalization_2038 (Normalizati (None, 1)            3           loudness_sma3_percentile80.0[0][0
# __________________________________________________________________________________________________
# normalization_2039 (Normalizati (None, 1)            3           loudness_sma3_pctlrange0-2[0][0]
# __________________________________________________________________________________________________
# normalization_2040 (Normalizati (None, 1)            3           loudness_sma3_meanRisingSlope[0][
# __________________________________________________________________________________________________
# normalization_2041 (Normalizati (None, 1)            3           loudness_sma3_stddevRisingSlope[0
# __________________________________________________________________________________________________
# normalization_2042 (Normalizati (None, 1)            3           loudness_sma3_meanFallingSlope[0]
# __________________________________________________________________________________________________
# normalization_2043 (Normalizati (None, 1)            3           loudness_sma3_stddevFallingSlope[
# __________________________________________________________________________________________________
# normalization_2044 (Normalizati (None, 1)            3           spectralFlux_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2045 (Normalizati (None, 1)            3           spectralFlux_sma3_stddevNorm[0][0
# __________________________________________________________________________________________________
# normalization_2046 (Normalizati (None, 1)            3           mfcc1_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2047 (Normalizati (None, 1)            3           mfcc1_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_2048 (Normalizati (None, 1)            3           mfcc2_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2049 (Normalizati (None, 1)            3           mfcc2_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_2050 (Normalizati (None, 1)            3           mfcc3_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2051 (Normalizati (None, 1)            3           mfcc3_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_2052 (Normalizati (None, 1)            3           mfcc4_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2053 (Normalizati (None, 1)            3           mfcc4_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_2054 (Normalizati (None, 1)            3           jitterLocal_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2055 (Normalizati (None, 1)            3           jitterLocal_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_2056 (Normalizati (None, 1)            3           shimmerLocaldB_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2057 (Normalizati (None, 1)            3           shimmerLocaldB_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_2058 (Normalizati (None, 1)            3           HNRdBACF_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2059 (Normalizati (None, 1)            3           HNRdBACF_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_2060 (Normalizati (None, 1)            3           logRelF0-H1-H2_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2061 (Normalizati (None, 1)            3           logRelF0-H1-H2_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_2062 (Normalizati (None, 1)            3           logRelF0-H1-A3_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2063 (Normalizati (None, 1)            3           logRelF0-H1-A3_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_2064 (Normalizati (None, 1)            3           F1frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2065 (Normalizati (None, 1)            3           F1frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_2066 (Normalizati (None, 1)            3           F1bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2067 (Normalizati (None, 1)            3           F1bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_2068 (Normalizati (None, 1)            3           F1amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_2069 (Normalizati (None, 1)            3           F1amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_2070 (Normalizati (None, 1)            3           F2frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2071 (Normalizati (None, 1)            3           F2frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_2072 (Normalizati (None, 1)            3           F2bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2073 (Normalizati (None, 1)            3           F2bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_2074 (Normalizati (None, 1)            3           F2amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_2075 (Normalizati (None, 1)            3           F2amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_2076 (Normalizati (None, 1)            3           F3frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2077 (Normalizati (None, 1)            3           F3frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_2078 (Normalizati (None, 1)            3           F3bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2079 (Normalizati (None, 1)            3           F3bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_2080 (Normalizati (None, 1)            3           F3amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_2081 (Normalizati (None, 1)            3           F3amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_2082 (Normalizati (None, 1)            3           alphaRatioV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2083 (Normalizati (None, 1)            3           alphaRatioV_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_2084 (Normalizati (None, 1)            3           hammarbergIndexV_sma3nz_amean[0][
# __________________________________________________________________________________________________
# normalization_2085 (Normalizati (None, 1)            3           hammarbergIndexV_sma3nz_stddevNor
# __________________________________________________________________________________________________
# normalization_2086 (Normalizati (None, 1)            3           slopeV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2087 (Normalizati (None, 1)            3           slopeV0-500_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_2088 (Normalizati (None, 1)            3           slopeV500-1500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2089 (Normalizati (None, 1)            3           slopeV500-1500_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_2090 (Normalizati (None, 1)            3           spectralFluxV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2091 (Normalizati (None, 1)            3           spectralFluxV_sma3nz_stddevNorm[0
# __________________________________________________________________________________________________
# normalization_2092 (Normalizati (None, 1)            3           mfcc1V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2093 (Normalizati (None, 1)            3           mfcc1V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_2094 (Normalizati (None, 1)            3           mfcc2V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2095 (Normalizati (None, 1)            3           mfcc2V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_2096 (Normalizati (None, 1)            3           mfcc3V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2097 (Normalizati (None, 1)            3           mfcc3V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_2098 (Normalizati (None, 1)            3           mfcc4V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2099 (Normalizati (None, 1)            3           mfcc4V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_2100 (Normalizati (None, 1)            3           alphaRatioUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2101 (Normalizati (None, 1)            3           hammarbergIndexUV_sma3nz_amean[0]
# __________________________________________________________________________________________________
# normalization_2102 (Normalizati (None, 1)            3           slopeUV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2103 (Normalizati (None, 1)            3           slopeUV500-1500_sma3nz_amean[0][0
# __________________________________________________________________________________________________
# normalization_2104 (Normalizati (None, 1)            3           spectralFluxUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_2105 (Normalizati (None, 1)            3           loudnessPeaksPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_2106 (Normalizati (None, 1)            3           VoicedSegmentsPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_2107 (Normalizati (None, 1)            3           MeanVoicedSegmentLengthSec[0][0]
# __________________________________________________________________________________________________
# normalization_2108 (Normalizati (None, 1)            3           StddevVoicedSegmentLengthSec[0][0
# __________________________________________________________________________________________________
# normalization_2109 (Normalizati (None, 1)            3           MeanUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_2110 (Normalizati (None, 1)            3           StddevUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_2111 (Normalizati (None, 1)            3           equivalentSoundLevel_dBp[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 88)           0           normalization_2024[0][0]
#                                                                  normalization_2025[0][0]
#                                                                  normalization_2026[0][0]
#                                                                  normalization_2027[0][0]
#                                                                  normalization_2028[0][0]
#                                                                  normalization_2029[0][0]
#                                                                  normalization_2030[0][0]
#                                                                  normalization_2031[0][0]
#                                                                  normalization_2032[0][0]
#                                                                  normalization_2033[0][0]
#                                                                  normalization_2034[0][0]
#                                                                  normalization_2035[0][0]
#                                                                  normalization_2036[0][0]
#                                                                  normalization_2037[0][0]
#                                                                  normalization_2038[0][0]
#                                                                  normalization_2039[0][0]
#                                                                  normalization_2040[0][0]
#                                                                  normalization_2041[0][0]
#                                                                  normalization_2042[0][0]
#                                                                  normalization_2043[0][0]
#                                                                  normalization_2044[0][0]
#                                                                  normalization_2045[0][0]
#                                                                  normalization_2046[0][0]
#                                                                  normalization_2047[0][0]
#                                                                  normalization_2048[0][0]
#                                                                  normalization_2049[0][0]
#                                                                  normalization_2050[0][0]
#                                                                  normalization_2051[0][0]
#                                                                  normalization_2052[0][0]
#                                                                  normalization_2053[0][0]
#                                                                  normalization_2054[0][0]
#                                                                  normalization_2055[0][0]
#                                                                  normalization_2056[0][0]
#                                                                  normalization_2057[0][0]
#                                                                  normalization_2058[0][0]
#                                                                  normalization_2059[0][0]
#                                                                  normalization_2060[0][0]
#                                                                  normalization_2061[0][0]
#                                                                  normalization_2062[0][0]
#                                                                  normalization_2063[0][0]
#                                                                  normalization_2064[0][0]
#                                                                  normalization_2065[0][0]
#                                                                  normalization_2066[0][0]
#                                                                  normalization_2067[0][0]
#                                                                  normalization_2068[0][0]
#                                                                  normalization_2069[0][0]
#                                                                  normalization_2070[0][0]
#                                                                  normalization_2071[0][0]
#                                                                  normalization_2072[0][0]
#                                                                  normalization_2073[0][0]
#                                                                  normalization_2074[0][0]
#                                                                  normalization_2075[0][0]
#                                                                  normalization_2076[0][0]
#                                                                  normalization_2077[0][0]
#                                                                  normalization_2078[0][0]
#                                                                  normalization_2079[0][0]
#                                                                  normalization_2080[0][0]
#                                                                  normalization_2081[0][0]
#                                                                  normalization_2082[0][0]
#                                                                  normalization_2083[0][0]
#                                                                  normalization_2084[0][0]
#                                                                  normalization_2085[0][0]
#                                                                  normalization_2086[0][0]
#                                                                  normalization_2087[0][0]
#                                                                  normalization_2088[0][0]
#                                                                  normalization_2089[0][0]
#                                                                  normalization_2090[0][0]
#                                                                  normalization_2091[0][0]
#                                                                  normalization_2092[0][0]
#                                                                  normalization_2093[0][0]
#                                                                  normalization_2094[0][0]
#                                                                  normalization_2095[0][0]
#                                                                  normalization_2096[0][0]
#                                                                  normalization_2097[0][0]
#                                                                  normalization_2098[0][0]
#                                                                  normalization_2099[0][0]
#                                                                  normalization_2100[0][0]
#                                                                  normalization_2101[0][0]
#                                                                  normalization_2102[0][0]
#                                                                  normalization_2103[0][0]
#                                                                  normalization_2104[0][0]
#                                                                  normalization_2105[0][0]
#                                                                  normalization_2106[0][0]
#                                                                  normalization_2107[0][0]
#                                                                  normalization_2108[0][0]
#                                                                  normalization_2109[0][0]
#                                                                  normalization_2110[0][0]
#                                                                  normalization_2111[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 128)          11392       concatenate_23[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 128)          0           dense_46[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 1)            129         dropout_23[0][0]
# ==================================================================================================
# Total params: 11,785
# Trainable params: 11,521
# Non-trainable params: 264
# __________________________________________________________________________________________________
# None

# %% [markdown]
# <a id='id2'></a>

# %%
def data_model(path, save_path, save_name_start = 'train', iter_num = 5, epoch_num =20, neurons = 32):
    """
    Function that creates datasets out of csv files and normalizes them using Keras layer preprocessing. Then a model is 
    created     and trained multiple times. Then it's metrics are saved and their summary is printed in the console.
    
    Parameters:
    path - filepath of the csv document with features
    save_path - directory where model metrics will be saved
    save_name_start - beginning of each saved file
    iter_num - number of Kfold splits
    epoch_num - number of epochs
    neurons - number of neurons on first dense layer
    
    Returns:
    df - Padnas DataFrame with best metrics from each cycle
    summary - model summary
    """
    try:
        makedirs(save_path)
    except:
        pass
    save_path = save_path+save_name_start
    file = path
    df = pd.read_csv(file)
    df.drop('Unnamed: 0', axis=1, inplace = True)
    base = list(range(0,int(len(df)/5))) #array of numbers equal to number of whole samples
    
    # Defining list to store best values
    best_loss = []
    best_acc = []
    best_loss_val = []
    best_acc_val = []
    batch_size = 20
    iterator = 0
    kfold = KFold(n_splits=iter_num, shuffle=True)
    
    for train_base, val_base in kfold.split(base):
        train = pd.DataFrame(load_subsample_data(train_base, df),columns=df.columns)
        val = pd.DataFrame(load_subsample_data(val_base, df),columns=df.columns)
        train_ds = df_to_dataset(train, batch_size=batch_size)
        column_list = train.columns[0:-1]
        all_inputs = []
        encoded_features = []
        count = 0
        for header in column_list:
            count += 1
            print('Processed %d column out of %d' % (count, len(column_list)), end="\r", flush=True)
            numeric_col = tf.keras.Input(shape=(1,), name=header)
            normalization_layer = get_normalization_layer(header, train_ds)
            encoded_numeric_col = normalization_layer(numeric_col)
            all_inputs.append(numeric_col)
            encoded_features.append(encoded_numeric_col)

        print("")
        # Build model
        all_features = tf.keras.layers.concatenate(encoded_features)
        x = tf.keras.layers.Dense(neurons, activation="relu")(all_features)
        x = tf.keras.layers.Dense(neurons, activation="relu")(x)
        x = tf.keras.layers.Dropout(0.4)(x)
        output = tf.keras.layers.Dense(1)(x)
        val_ds = df_to_dataset(val, shuffle=False, batch_size=batch_size)
        iterator += 1
        print('Training cycle %d out of %d' % (iterator, iter_num), end="\r", flush=True)
        model = tf.keras.Model(all_inputs, output)
        model.compile(optimizer='adam',
                      loss=tf.keras.losses.BinaryCrossentropy(),
                      metrics=["accuracy"])
        model.fit(train_ds, epochs=epoch_num, validation_data=val_ds, verbose=0)
        df2 = pd.DataFrame()
        for part in ['loss', 'accuracy', 'val_loss', 'val_accuracy']: 
            df2[part] = model.history.history[part]
        df2.index.names = ['Epoch']
        df2.to_csv(save_path+'_training'+str(iterator)+'.csv')

        # Save best values
        best_loss.append(max(model.history.history['loss']))
        best_acc.append(max(model.history.history['accuracy']))
        best_loss_val.append(max(model.history.history['val_loss']))
        best_acc_val.append(max(model.history.history['val_accuracy']))
        print("")
    
    # Post training
    summary = model.summary # Every model is the same so the summary can be called post training loop
    df = pd.DataFrame()
    df['Best_Loss'] = best_loss
    df['Best_Acc'] = best_acc
    df['Best_Loss_Val'] = best_loss_val
    df['Best_Acc_Val'] = best_acc_val
    df.index.names = ['Model_Num']
    df.to_csv(save_path+'_best'+'.csv')
    return df, summary

# %%
start_time_full = time.time()
for number in [32, 64, 128]:
    print('Model training: ')
    print('')
    print('---------------------------------------------------------------------------------------------------------------')
    print('')
    print('\t \t \t Processing layers ', str(number))
    print('')
    print('---------------------------------------------------------------------------------------------------------------')
    print('')
    start_time = time.time()
    df, summary = data_model('./csvs/eGeMAPS/ReadText_eGeMAPSv01b.csv',
                             './layer_test_train_outputs/id2/'+str(number)+'/', 
                             'Id1', iter_num=8, epoch_num=100, neurons=number)
    print('Elapsed time: ' , time.time() - start_time)

print('Full elapsed time: ' , time.time() - start_time_full)
print(summary())
# Out:
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  32
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  143.22636890411377
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  64
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  144.25934052467346
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  128
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  145.8438196182251
# Full elapsed time:  433.32952904701233
# Model: "functional_95"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# F0semitoneFrom27.5Hz_sma3nz_ame [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_pct [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile20.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile50.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile80.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_pctlrange0-2 (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanRisingSlope ( [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevRisingSlope [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanFallingSlope  [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevFallingSlop [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFlux_sma3_amean (InputL [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFlux_sma3_stddevNorm (I [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_amean (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_stddevNorm (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_amean ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_stddevN [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxV_sma3nz_amean (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxV_sma3nz_stddevNorm [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioUV_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexUV_sma3nz_amean  [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV0-500_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV500-1500_sma3nz_amean (I [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxUV_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# loudnessPeaksPerSec (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# VoicedSegmentsPerSec (InputLaye [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanVoicedSegmentLengthSec (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevVoicedSegmentLengthSec (I [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanUnvoicedSegmentLength (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevUnvoicedSegmentLength (In [(None, 1)]          0
# __________________________________________________________________________________________________
# equivalentSoundLevel_dBp (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# normalization_4136 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_amean
# __________________________________________________________________________________________________
# normalization_4137 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_4138 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_4139 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_4140 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_4141 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_pctlr
# __________________________________________________________________________________________________
# normalization_4142 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanR
# __________________________________________________________________________________________________
# normalization_4143 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_4144 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanF
# __________________________________________________________________________________________________
# normalization_4145 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_4146 (Normalizati (None, 1)            3           loudness_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4147 (Normalizati (None, 1)            3           loudness_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_4148 (Normalizati (None, 1)            3           loudness_sma3_percentile20.0[0][0
# __________________________________________________________________________________________________
# normalization_4149 (Normalizati (None, 1)            3           loudness_sma3_percentile50.0[0][0
# __________________________________________________________________________________________________
# normalization_4150 (Normalizati (None, 1)            3           loudness_sma3_percentile80.0[0][0
# __________________________________________________________________________________________________
# normalization_4151 (Normalizati (None, 1)            3           loudness_sma3_pctlrange0-2[0][0]
# __________________________________________________________________________________________________
# normalization_4152 (Normalizati (None, 1)            3           loudness_sma3_meanRisingSlope[0][
# __________________________________________________________________________________________________
# normalization_4153 (Normalizati (None, 1)            3           loudness_sma3_stddevRisingSlope[0
# __________________________________________________________________________________________________
# normalization_4154 (Normalizati (None, 1)            3           loudness_sma3_meanFallingSlope[0]
# __________________________________________________________________________________________________
# normalization_4155 (Normalizati (None, 1)            3           loudness_sma3_stddevFallingSlope[
# __________________________________________________________________________________________________
# normalization_4156 (Normalizati (None, 1)            3           spectralFlux_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4157 (Normalizati (None, 1)            3           spectralFlux_sma3_stddevNorm[0][0
# __________________________________________________________________________________________________
# normalization_4158 (Normalizati (None, 1)            3           mfcc1_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4159 (Normalizati (None, 1)            3           mfcc1_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_4160 (Normalizati (None, 1)            3           mfcc2_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4161 (Normalizati (None, 1)            3           mfcc2_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_4162 (Normalizati (None, 1)            3           mfcc3_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4163 (Normalizati (None, 1)            3           mfcc3_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_4164 (Normalizati (None, 1)            3           mfcc4_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4165 (Normalizati (None, 1)            3           mfcc4_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_4166 (Normalizati (None, 1)            3           jitterLocal_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4167 (Normalizati (None, 1)            3           jitterLocal_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_4168 (Normalizati (None, 1)            3           shimmerLocaldB_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4169 (Normalizati (None, 1)            3           shimmerLocaldB_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_4170 (Normalizati (None, 1)            3           HNRdBACF_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4171 (Normalizati (None, 1)            3           HNRdBACF_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_4172 (Normalizati (None, 1)            3           logRelF0-H1-H2_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4173 (Normalizati (None, 1)            3           logRelF0-H1-H2_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_4174 (Normalizati (None, 1)            3           logRelF0-H1-A3_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4175 (Normalizati (None, 1)            3           logRelF0-H1-A3_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_4176 (Normalizati (None, 1)            3           F1frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4177 (Normalizati (None, 1)            3           F1frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_4178 (Normalizati (None, 1)            3           F1bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4179 (Normalizati (None, 1)            3           F1bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_4180 (Normalizati (None, 1)            3           F1amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_4181 (Normalizati (None, 1)            3           F1amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_4182 (Normalizati (None, 1)            3           F2frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4183 (Normalizati (None, 1)            3           F2frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_4184 (Normalizati (None, 1)            3           F2bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4185 (Normalizati (None, 1)            3           F2bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_4186 (Normalizati (None, 1)            3           F2amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_4187 (Normalizati (None, 1)            3           F2amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_4188 (Normalizati (None, 1)            3           F3frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4189 (Normalizati (None, 1)            3           F3frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_4190 (Normalizati (None, 1)            3           F3bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4191 (Normalizati (None, 1)            3           F3bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_4192 (Normalizati (None, 1)            3           F3amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_4193 (Normalizati (None, 1)            3           F3amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_4194 (Normalizati (None, 1)            3           alphaRatioV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4195 (Normalizati (None, 1)            3           alphaRatioV_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_4196 (Normalizati (None, 1)            3           hammarbergIndexV_sma3nz_amean[0][
# __________________________________________________________________________________________________
# normalization_4197 (Normalizati (None, 1)            3           hammarbergIndexV_sma3nz_stddevNor
# __________________________________________________________________________________________________
# normalization_4198 (Normalizati (None, 1)            3           slopeV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4199 (Normalizati (None, 1)            3           slopeV0-500_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_4200 (Normalizati (None, 1)            3           slopeV500-1500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4201 (Normalizati (None, 1)            3           slopeV500-1500_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_4202 (Normalizati (None, 1)            3           spectralFluxV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4203 (Normalizati (None, 1)            3           spectralFluxV_sma3nz_stddevNorm[0
# __________________________________________________________________________________________________
# normalization_4204 (Normalizati (None, 1)            3           mfcc1V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4205 (Normalizati (None, 1)            3           mfcc1V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_4206 (Normalizati (None, 1)            3           mfcc2V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4207 (Normalizati (None, 1)            3           mfcc2V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_4208 (Normalizati (None, 1)            3           mfcc3V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4209 (Normalizati (None, 1)            3           mfcc3V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_4210 (Normalizati (None, 1)            3           mfcc4V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4211 (Normalizati (None, 1)            3           mfcc4V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_4212 (Normalizati (None, 1)            3           alphaRatioUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4213 (Normalizati (None, 1)            3           hammarbergIndexUV_sma3nz_amean[0]
# __________________________________________________________________________________________________
# normalization_4214 (Normalizati (None, 1)            3           slopeUV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4215 (Normalizati (None, 1)            3           slopeUV500-1500_sma3nz_amean[0][0
# __________________________________________________________________________________________________
# normalization_4216 (Normalizati (None, 1)            3           spectralFluxUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_4217 (Normalizati (None, 1)            3           loudnessPeaksPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_4218 (Normalizati (None, 1)            3           VoicedSegmentsPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_4219 (Normalizati (None, 1)            3           MeanVoicedSegmentLengthSec[0][0]
# __________________________________________________________________________________________________
# normalization_4220 (Normalizati (None, 1)            3           StddevVoicedSegmentLengthSec[0][0
# __________________________________________________________________________________________________
# normalization_4221 (Normalizati (None, 1)            3           MeanUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_4222 (Normalizati (None, 1)            3           StddevUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_4223 (Normalizati (None, 1)            3           equivalentSoundLevel_dBp[0][0]
# __________________________________________________________________________________________________
# concatenate_47 (Concatenate)    (None, 88)           0           normalization_4136[0][0]
#                                                                  normalization_4137[0][0]
#                                                                  normalization_4138[0][0]
#                                                                  normalization_4139[0][0]
#                                                                  normalization_4140[0][0]
#                                                                  normalization_4141[0][0]
#                                                                  normalization_4142[0][0]
#                                                                  normalization_4143[0][0]
#                                                                  normalization_4144[0][0]
#                                                                  normalization_4145[0][0]
#                                                                  normalization_4146[0][0]
#                                                                  normalization_4147[0][0]
#                                                                  normalization_4148[0][0]
#                                                                  normalization_4149[0][0]
#                                                                  normalization_4150[0][0]
#                                                                  normalization_4151[0][0]
#                                                                  normalization_4152[0][0]
#                                                                  normalization_4153[0][0]
#                                                                  normalization_4154[0][0]
#                                                                  normalization_4155[0][0]
#                                                                  normalization_4156[0][0]
#                                                                  normalization_4157[0][0]
#                                                                  normalization_4158[0][0]
#                                                                  normalization_4159[0][0]
#                                                                  normalization_4160[0][0]
#                                                                  normalization_4161[0][0]
#                                                                  normalization_4162[0][0]
#                                                                  normalization_4163[0][0]
#                                                                  normalization_4164[0][0]
#                                                                  normalization_4165[0][0]
#                                                                  normalization_4166[0][0]
#                                                                  normalization_4167[0][0]
#                                                                  normalization_4168[0][0]
#                                                                  normalization_4169[0][0]
#                                                                  normalization_4170[0][0]
#                                                                  normalization_4171[0][0]
#                                                                  normalization_4172[0][0]
#                                                                  normalization_4173[0][0]
#                                                                  normalization_4174[0][0]
#                                                                  normalization_4175[0][0]
#                                                                  normalization_4176[0][0]
#                                                                  normalization_4177[0][0]
#                                                                  normalization_4178[0][0]
#                                                                  normalization_4179[0][0]
#                                                                  normalization_4180[0][0]
#                                                                  normalization_4181[0][0]
#                                                                  normalization_4182[0][0]
#                                                                  normalization_4183[0][0]
#                                                                  normalization_4184[0][0]
#                                                                  normalization_4185[0][0]
#                                                                  normalization_4186[0][0]
#                                                                  normalization_4187[0][0]
#                                                                  normalization_4188[0][0]
#                                                                  normalization_4189[0][0]
#                                                                  normalization_4190[0][0]
#                                                                  normalization_4191[0][0]
#                                                                  normalization_4192[0][0]
#                                                                  normalization_4193[0][0]
#                                                                  normalization_4194[0][0]
#                                                                  normalization_4195[0][0]
#                                                                  normalization_4196[0][0]
#                                                                  normalization_4197[0][0]
#                                                                  normalization_4198[0][0]
#                                                                  normalization_4199[0][0]
#                                                                  normalization_4200[0][0]
#                                                                  normalization_4201[0][0]
#                                                                  normalization_4202[0][0]
#                                                                  normalization_4203[0][0]
#                                                                  normalization_4204[0][0]
#                                                                  normalization_4205[0][0]
#                                                                  normalization_4206[0][0]
#                                                                  normalization_4207[0][0]
#                                                                  normalization_4208[0][0]
#                                                                  normalization_4209[0][0]
#                                                                  normalization_4210[0][0]
#                                                                  normalization_4211[0][0]
#                                                                  normalization_4212[0][0]
#                                                                  normalization_4213[0][0]
#                                                                  normalization_4214[0][0]
#                                                                  normalization_4215[0][0]
#                                                                  normalization_4216[0][0]
#                                                                  normalization_4217[0][0]
#                                                                  normalization_4218[0][0]
#                                                                  normalization_4219[0][0]
#                                                                  normalization_4220[0][0]
#                                                                  normalization_4221[0][0]
#                                                                  normalization_4222[0][0]
#                                                                  normalization_4223[0][0]
# __________________________________________________________________________________________________
# dense_117 (Dense)               (None, 128)          11392       concatenate_47[0][0]
# __________________________________________________________________________________________________
# dense_118 (Dense)               (None, 128)          16512       dense_117[0][0]
# __________________________________________________________________________________________________
# dropout_47 (Dropout)            (None, 128)          0           dense_118[0][0]
# __________________________________________________________________________________________________
# dense_119 (Dense)               (None, 1)            129         dropout_47[0][0]
# ==================================================================================================
# Total params: 28,297
# Trainable params: 28,033
# Non-trainable params: 264
# __________________________________________________________________________________________________
# None

# %% [markdown]
# <a id='id3'></a>

# %%
def data_model(path, save_path, save_name_start = 'train', iter_num = 5, epoch_num =20, neurons = 32):
    """
    Function that creates datasets out of csv files and normalizes them using Keras layer preprocessing. Then a model is 
    created     and trained multiple times. Then it's metrics are saved and their summary is printed in the console.
    
    Parameters:
    path - filepath of the csv document with features
    save_path - directory where model metrics will be saved
    save_name_start - beginning of each saved file
    iter_num - number of Kfold splits
    epoch_num - number of epochs
    neurons - number of neurons on first dense layer
    
    Returns:
    df - Padnas DataFrame with best metrics from each cycle
    summary - model summary
    """
    try:
        makedirs(save_path)
    except:
        pass
    save_path = save_path+save_name_start
    file = path
    df = pd.read_csv(file)
    df.drop('Unnamed: 0', axis=1, inplace = True)
    base = list(range(0,int(len(df)/5))) #array of numbers equal to number of whole samples
    
    # Defining list to store best values
    best_loss = []
    best_acc = []
    best_loss_val = []
    best_acc_val = []
    batch_size = 20
    iterator = 0
    kfold = KFold(n_splits=iter_num, shuffle=True)
    
    for train_base, val_base in kfold.split(base):
        train = pd.DataFrame(load_subsample_data(train_base, df),columns=df.columns)
        val = pd.DataFrame(load_subsample_data(val_base, df),columns=df.columns)
        train_ds = df_to_dataset(train, batch_size=batch_size)
        column_list = train.columns[0:-1]
        all_inputs = []
        encoded_features = []
        count = 0
        for header in column_list:
            count += 1
            print('Processed %d column out of %d' % (count, len(column_list)), end="\r", flush=True)
            numeric_col = tf.keras.Input(shape=(1,), name=header)
            normalization_layer = get_normalization_layer(header, train_ds)
            encoded_numeric_col = normalization_layer(numeric_col)
            all_inputs.append(numeric_col)
            encoded_features.append(encoded_numeric_col)

        print("")
        # Build model
        all_features = tf.keras.layers.concatenate(encoded_features)
        x = tf.keras.layers.Dense(neurons, activation="relu")(all_features)
        x = tf.keras.layers.Dense(int(neurons/2), activation="relu")(x)
        x = tf.keras.layers.Dropout(0.4)(x)
        output = tf.keras.layers.Dense(1)(x)
        val_ds = df_to_dataset(val, shuffle=False, batch_size=batch_size)
        iterator += 1
        print('Training cycle %d out of %d' % (iterator, iter_num), end="\r", flush=True)
        model = tf.keras.Model(all_inputs, output)
        model.compile(optimizer='adam',
                      loss=tf.keras.losses.BinaryCrossentropy(),
                      metrics=["accuracy"])
        model.fit(train_ds, epochs=epoch_num, validation_data=val_ds, verbose=0)
        df2 = pd.DataFrame()
        for part in ['loss', 'accuracy', 'val_loss', 'val_accuracy']: 
            df2[part] = model.history.history[part]
        df2.index.names = ['Epoch']
        df2.to_csv(save_path+'_training'+str(iterator)+'.csv')

        # Save best values
        best_loss.append(max(model.history.history['loss']))
        best_acc.append(max(model.history.history['accuracy']))
        best_loss_val.append(max(model.history.history['val_loss']))
        best_acc_val.append(max(model.history.history['val_accuracy']))
        print("")
    
    # Post training
    summary = model.summary # Every model is the same so the summary can be called post training loop
    df = pd.DataFrame()
    df['Best_Loss'] = best_loss
    df['Best_Acc'] = best_acc
    df['Best_Loss_Val'] = best_loss_val
    df['Best_Acc_Val'] = best_acc_val
    df.index.names = ['Model_Num']
    df.to_csv(save_path+'_best'+'.csv')
    return df, summary

# %%
start_time_full = time.time()
for number in [32, 64, 128]:
    print('Model training: ')
    print('')
    print('---------------------------------------------------------------------------------------------------------------')
    print('')
    print('\t \t \t Processing layers ', str(number))
    print('')
    print('---------------------------------------------------------------------------------------------------------------')
    print('')
    start_time = time.time()
    df, summary = data_model('./csvs/eGeMAPS/ReadText_eGeMAPSv01b.csv',
                             './layer_test_train_outputs/id3/'+str(number)+'/', 
                             'Id1', iter_num=8, epoch_num=100, neurons=number)
    print('Elapsed time: ' , time.time() - start_time)

print('Full elapsed time: ' , time.time() - start_time_full)
print(summary())
# Out:
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  32
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  147.7011594772339
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  64
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  146.13367891311646
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  128
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  145.48996806144714
# Full elapsed time:  439.3248064517975
# Model: "functional_143"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# F0semitoneFrom27.5Hz_sma3nz_ame [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_pct [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile20.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile50.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile80.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_pctlrange0-2 (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanRisingSlope ( [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevRisingSlope [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanFallingSlope  [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevFallingSlop [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFlux_sma3_amean (InputL [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFlux_sma3_stddevNorm (I [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_amean (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_stddevNorm (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_amean ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_stddevN [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxV_sma3nz_amean (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxV_sma3nz_stddevNorm [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioUV_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexUV_sma3nz_amean  [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV0-500_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV500-1500_sma3nz_amean (I [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxUV_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# loudnessPeaksPerSec (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# VoicedSegmentsPerSec (InputLaye [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanVoicedSegmentLengthSec (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevVoicedSegmentLengthSec (I [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanUnvoicedSegmentLength (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevUnvoicedSegmentLength (In [(None, 1)]          0
# __________________________________________________________________________________________________
# equivalentSoundLevel_dBp (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# normalization_6248 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_amean
# __________________________________________________________________________________________________
# normalization_6249 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_6250 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_6251 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_6252 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_6253 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_pctlr
# __________________________________________________________________________________________________
# normalization_6254 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanR
# __________________________________________________________________________________________________
# normalization_6255 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_6256 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanF
# __________________________________________________________________________________________________
# normalization_6257 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_6258 (Normalizati (None, 1)            3           loudness_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6259 (Normalizati (None, 1)            3           loudness_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_6260 (Normalizati (None, 1)            3           loudness_sma3_percentile20.0[0][0
# __________________________________________________________________________________________________
# normalization_6261 (Normalizati (None, 1)            3           loudness_sma3_percentile50.0[0][0
# __________________________________________________________________________________________________
# normalization_6262 (Normalizati (None, 1)            3           loudness_sma3_percentile80.0[0][0
# __________________________________________________________________________________________________
# normalization_6263 (Normalizati (None, 1)            3           loudness_sma3_pctlrange0-2[0][0]
# __________________________________________________________________________________________________
# normalization_6264 (Normalizati (None, 1)            3           loudness_sma3_meanRisingSlope[0][
# __________________________________________________________________________________________________
# normalization_6265 (Normalizati (None, 1)            3           loudness_sma3_stddevRisingSlope[0
# __________________________________________________________________________________________________
# normalization_6266 (Normalizati (None, 1)            3           loudness_sma3_meanFallingSlope[0]
# __________________________________________________________________________________________________
# normalization_6267 (Normalizati (None, 1)            3           loudness_sma3_stddevFallingSlope[
# __________________________________________________________________________________________________
# normalization_6268 (Normalizati (None, 1)            3           spectralFlux_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6269 (Normalizati (None, 1)            3           spectralFlux_sma3_stddevNorm[0][0
# __________________________________________________________________________________________________
# normalization_6270 (Normalizati (None, 1)            3           mfcc1_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6271 (Normalizati (None, 1)            3           mfcc1_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_6272 (Normalizati (None, 1)            3           mfcc2_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6273 (Normalizati (None, 1)            3           mfcc2_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_6274 (Normalizati (None, 1)            3           mfcc3_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6275 (Normalizati (None, 1)            3           mfcc3_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_6276 (Normalizati (None, 1)            3           mfcc4_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6277 (Normalizati (None, 1)            3           mfcc4_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_6278 (Normalizati (None, 1)            3           jitterLocal_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6279 (Normalizati (None, 1)            3           jitterLocal_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_6280 (Normalizati (None, 1)            3           shimmerLocaldB_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6281 (Normalizati (None, 1)            3           shimmerLocaldB_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_6282 (Normalizati (None, 1)            3           HNRdBACF_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6283 (Normalizati (None, 1)            3           HNRdBACF_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_6284 (Normalizati (None, 1)            3           logRelF0-H1-H2_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6285 (Normalizati (None, 1)            3           logRelF0-H1-H2_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_6286 (Normalizati (None, 1)            3           logRelF0-H1-A3_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6287 (Normalizati (None, 1)            3           logRelF0-H1-A3_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_6288 (Normalizati (None, 1)            3           F1frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6289 (Normalizati (None, 1)            3           F1frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_6290 (Normalizati (None, 1)            3           F1bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6291 (Normalizati (None, 1)            3           F1bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_6292 (Normalizati (None, 1)            3           F1amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_6293 (Normalizati (None, 1)            3           F1amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_6294 (Normalizati (None, 1)            3           F2frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6295 (Normalizati (None, 1)            3           F2frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_6296 (Normalizati (None, 1)            3           F2bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6297 (Normalizati (None, 1)            3           F2bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_6298 (Normalizati (None, 1)            3           F2amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_6299 (Normalizati (None, 1)            3           F2amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_6300 (Normalizati (None, 1)            3           F3frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6301 (Normalizati (None, 1)            3           F3frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_6302 (Normalizati (None, 1)            3           F3bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6303 (Normalizati (None, 1)            3           F3bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_6304 (Normalizati (None, 1)            3           F3amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_6305 (Normalizati (None, 1)            3           F3amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_6306 (Normalizati (None, 1)            3           alphaRatioV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6307 (Normalizati (None, 1)            3           alphaRatioV_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_6308 (Normalizati (None, 1)            3           hammarbergIndexV_sma3nz_amean[0][
# __________________________________________________________________________________________________
# normalization_6309 (Normalizati (None, 1)            3           hammarbergIndexV_sma3nz_stddevNor
# __________________________________________________________________________________________________
# normalization_6310 (Normalizati (None, 1)            3           slopeV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6311 (Normalizati (None, 1)            3           slopeV0-500_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_6312 (Normalizati (None, 1)            3           slopeV500-1500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6313 (Normalizati (None, 1)            3           slopeV500-1500_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_6314 (Normalizati (None, 1)            3           spectralFluxV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6315 (Normalizati (None, 1)            3           spectralFluxV_sma3nz_stddevNorm[0
# __________________________________________________________________________________________________
# normalization_6316 (Normalizati (None, 1)            3           mfcc1V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6317 (Normalizati (None, 1)            3           mfcc1V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_6318 (Normalizati (None, 1)            3           mfcc2V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6319 (Normalizati (None, 1)            3           mfcc2V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_6320 (Normalizati (None, 1)            3           mfcc3V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6321 (Normalizati (None, 1)            3           mfcc3V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_6322 (Normalizati (None, 1)            3           mfcc4V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6323 (Normalizati (None, 1)            3           mfcc4V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_6324 (Normalizati (None, 1)            3           alphaRatioUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6325 (Normalizati (None, 1)            3           hammarbergIndexUV_sma3nz_amean[0]
# __________________________________________________________________________________________________
# normalization_6326 (Normalizati (None, 1)            3           slopeUV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6327 (Normalizati (None, 1)            3           slopeUV500-1500_sma3nz_amean[0][0
# __________________________________________________________________________________________________
# normalization_6328 (Normalizati (None, 1)            3           spectralFluxUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_6329 (Normalizati (None, 1)            3           loudnessPeaksPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_6330 (Normalizati (None, 1)            3           VoicedSegmentsPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_6331 (Normalizati (None, 1)            3           MeanVoicedSegmentLengthSec[0][0]
# __________________________________________________________________________________________________
# normalization_6332 (Normalizati (None, 1)            3           StddevVoicedSegmentLengthSec[0][0
# __________________________________________________________________________________________________
# normalization_6333 (Normalizati (None, 1)            3           MeanUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_6334 (Normalizati (None, 1)            3           StddevUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_6335 (Normalizati (None, 1)            3           equivalentSoundLevel_dBp[0][0]
# __________________________________________________________________________________________________
# concatenate_71 (Concatenate)    (None, 88)           0           normalization_6248[0][0]
#                                                                  normalization_6249[0][0]
#                                                                  normalization_6250[0][0]
#                                                                  normalization_6251[0][0]
#                                                                  normalization_6252[0][0]
#                                                                  normalization_6253[0][0]
#                                                                  normalization_6254[0][0]
#                                                                  normalization_6255[0][0]
#                                                                  normalization_6256[0][0]
#                                                                  normalization_6257[0][0]
#                                                                  normalization_6258[0][0]
#                                                                  normalization_6259[0][0]
#                                                                  normalization_6260[0][0]
#                                                                  normalization_6261[0][0]
#                                                                  normalization_6262[0][0]
#                                                                  normalization_6263[0][0]
#                                                                  normalization_6264[0][0]
#                                                                  normalization_6265[0][0]
#                                                                  normalization_6266[0][0]
#                                                                  normalization_6267[0][0]
#                                                                  normalization_6268[0][0]
#                                                                  normalization_6269[0][0]
#                                                                  normalization_6270[0][0]
#                                                                  normalization_6271[0][0]
#                                                                  normalization_6272[0][0]
#                                                                  normalization_6273[0][0]
#                                                                  normalization_6274[0][0]
#                                                                  normalization_6275[0][0]
#                                                                  normalization_6276[0][0]
#                                                                  normalization_6277[0][0]
#                                                                  normalization_6278[0][0]
#                                                                  normalization_6279[0][0]
#                                                                  normalization_6280[0][0]
#                                                                  normalization_6281[0][0]
#                                                                  normalization_6282[0][0]
#                                                                  normalization_6283[0][0]
#                                                                  normalization_6284[0][0]
#                                                                  normalization_6285[0][0]
#                                                                  normalization_6286[0][0]
#                                                                  normalization_6287[0][0]
#                                                                  normalization_6288[0][0]
#                                                                  normalization_6289[0][0]
#                                                                  normalization_6290[0][0]
#                                                                  normalization_6291[0][0]
#                                                                  normalization_6292[0][0]
#                                                                  normalization_6293[0][0]
#                                                                  normalization_6294[0][0]
#                                                                  normalization_6295[0][0]
#                                                                  normalization_6296[0][0]
#                                                                  normalization_6297[0][0]
#                                                                  normalization_6298[0][0]
#                                                                  normalization_6299[0][0]
#                                                                  normalization_6300[0][0]
#                                                                  normalization_6301[0][0]
#                                                                  normalization_6302[0][0]
#                                                                  normalization_6303[0][0]
#                                                                  normalization_6304[0][0]
#                                                                  normalization_6305[0][0]
#                                                                  normalization_6306[0][0]
#                                                                  normalization_6307[0][0]
#                                                                  normalization_6308[0][0]
#                                                                  normalization_6309[0][0]
#                                                                  normalization_6310[0][0]
#                                                                  normalization_6311[0][0]
#                                                                  normalization_6312[0][0]
#                                                                  normalization_6313[0][0]
#                                                                  normalization_6314[0][0]
#                                                                  normalization_6315[0][0]
#                                                                  normalization_6316[0][0]
#                                                                  normalization_6317[0][0]
#                                                                  normalization_6318[0][0]
#                                                                  normalization_6319[0][0]
#                                                                  normalization_6320[0][0]
#                                                                  normalization_6321[0][0]
#                                                                  normalization_6322[0][0]
#                                                                  normalization_6323[0][0]
#                                                                  normalization_6324[0][0]
#                                                                  normalization_6325[0][0]
#                                                                  normalization_6326[0][0]
#                                                                  normalization_6327[0][0]
#                                                                  normalization_6328[0][0]
#                                                                  normalization_6329[0][0]
#                                                                  normalization_6330[0][0]
#                                                                  normalization_6331[0][0]
#                                                                  normalization_6332[0][0]
#                                                                  normalization_6333[0][0]
#                                                                  normalization_6334[0][0]
#                                                                  normalization_6335[0][0]
# __________________________________________________________________________________________________
# dense_189 (Dense)               (None, 128)          11392       concatenate_71[0][0]
# __________________________________________________________________________________________________
# dense_190 (Dense)               (None, 64)           8256        dense_189[0][0]
# __________________________________________________________________________________________________
# dropout_71 (Dropout)            (None, 64)           0           dense_190[0][0]
# __________________________________________________________________________________________________
# dense_191 (Dense)               (None, 1)            65          dropout_71[0][0]
# ==================================================================================================
# Total params: 19,977
# Trainable params: 19,713
# Non-trainable params: 264
# __________________________________________________________________________________________________
# None

# %% [markdown]
# <a id='id4'></a>

# %%
def data_model(path, save_path, save_name_start = 'train', iter_num = 5, epoch_num =20, neurons = 32):
    """
    Function that creates datasets out of csv files and normalizes them using Keras layer preprocessing. Then a model is 
    created     and trained multiple times. Then it's metrics are saved and their summary is printed in the console.
    
    Parameters:
    path - filepath of the csv document with features
    save_path - directory where model metrics will be saved
    save_name_start - beginning of each saved file
    iter_num - number of Kfold splits
    epoch_num - number of epochs
    neurons - number of neurons on first dense layer
    
    Returns:
    df - Padnas DataFrame with best metrics from each cycle
    summary - model summary
    """
    try:
        makedirs(save_path)
    except:
        pass
    save_path = save_path+save_name_start
    file = path
    df = pd.read_csv(file)
    df.drop('Unnamed: 0', axis=1, inplace = True)
    base = list(range(0,int(len(df)/5))) #array of numbers equal to number of whole samples
    
    # Defining list to store best values
    best_loss = []
    best_acc = []
    best_loss_val = []
    best_acc_val = []
    batch_size = 20
    iterator = 0
    kfold = KFold(n_splits=iter_num, shuffle=True)
    
    for train_base, val_base in kfold.split(base):
        train = pd.DataFrame(load_subsample_data(train_base, df),columns=df.columns)
        val = pd.DataFrame(load_subsample_data(val_base, df),columns=df.columns)
        train_ds = df_to_dataset(train, batch_size=batch_size)
        column_list = train.columns[0:-1]
        all_inputs = []
        encoded_features = []
        count = 0
        for header in column_list:
            count += 1
            print('Processed %d column out of %d' % (count, len(column_list)), end="\r", flush=True)
            numeric_col = tf.keras.Input(shape=(1,), name=header)
            normalization_layer = get_normalization_layer(header, train_ds)
            encoded_numeric_col = normalization_layer(numeric_col)
            all_inputs.append(numeric_col)
            encoded_features.append(encoded_numeric_col)

        print("")
        # Build model
        all_features = tf.keras.layers.concatenate(encoded_features)
        x = tf.keras.layers.Dense(neurons, activation="relu")(all_features)
        x = tf.keras.layers.Dense(neurons, activation="relu")(x)
        x = tf.keras.layers.Dense(neurons, activation="relu")(x)
        x = tf.keras.layers.Dropout(0.4)(x)
        output = tf.keras.layers.Dense(1)(x)
        val_ds = df_to_dataset(val, shuffle=False, batch_size=batch_size)
        iterator += 1
        print('Training cycle %d out of %d' % (iterator, iter_num), end="\r", flush=True)
        model = tf.keras.Model(all_inputs, output)
        model.compile(optimizer='adam',
                      loss=tf.keras.losses.BinaryCrossentropy(),
                      metrics=["accuracy"])
        model.fit(train_ds, epochs=epoch_num, validation_data=val_ds, verbose=0)
        df2 = pd.DataFrame()
        for part in ['loss', 'accuracy', 'val_loss', 'val_accuracy']: 
            df2[part] = model.history.history[part]
        df2.index.names = ['Epoch']
        df2.to_csv(save_path+'_training'+str(iterator)+'.csv')

        # Save best values
        best_loss.append(max(model.history.history['loss']))
        best_acc.append(max(model.history.history['accuracy']))
        best_loss_val.append(max(model.history.history['val_loss']))
        best_acc_val.append(max(model.history.history['val_accuracy']))
        print("")
    
    # Post training
    summary = model.summary # Every model is the same so the summary can be called post training loop
    df = pd.DataFrame()
    df['Best_Loss'] = best_loss
    df['Best_Acc'] = best_acc
    df['Best_Loss_Val'] = best_loss_val
    df['Best_Acc_Val'] = best_acc_val
    df.index.names = ['Model_Num']
    df.to_csv(save_path+'_best'+'.csv')
    return df, summary

# %%
start_time_full = time.time()
for number in [32, 64, 128]:
    print('Model training: ')
    print('')
    print('---------------------------------------------------------------------------------------------------------------')
    print('')
    print('\t \t \t Processing layers ', str(number))
    print('')
    print('---------------------------------------------------------------------------------------------------------------')
    print('')
    start_time = time.time()
    df, summary = data_model('./csvs/eGeMAPS/ReadText_eGeMAPSv01b.csv',
                             './layer_test_train_outputs/id4/'+str(number)+'/', 
                             'Id1', iter_num=8, epoch_num=100, neurons=number)
    print('Elapsed time: ' , time.time() - start_time)

print('Full elapsed time: ' , time.time() - start_time_full)
print(summary())
# Out:
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  32
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  147.26812958717346
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  64
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  153.03930735588074
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  128
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  155.7674126625061
# Full elapsed time:  456.0748496055603
# Model: "functional_191"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# F0semitoneFrom27.5Hz_sma3nz_ame [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_pct [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile20.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile50.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile80.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_pctlrange0-2 (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanRisingSlope ( [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevRisingSlope [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanFallingSlope  [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevFallingSlop [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFlux_sma3_amean (InputL [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFlux_sma3_stddevNorm (I [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_amean (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_stddevNorm (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_amean ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_stddevN [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxV_sma3nz_amean (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxV_sma3nz_stddevNorm [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioUV_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexUV_sma3nz_amean  [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV0-500_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV500-1500_sma3nz_amean (I [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxUV_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# loudnessPeaksPerSec (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# VoicedSegmentsPerSec (InputLaye [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanVoicedSegmentLengthSec (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevVoicedSegmentLengthSec (I [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanUnvoicedSegmentLength (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevUnvoicedSegmentLength (In [(None, 1)]          0
# __________________________________________________________________________________________________
# equivalentSoundLevel_dBp (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# normalization_8360 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_amean
# __________________________________________________________________________________________________
# normalization_8361 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_8362 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_8363 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_8364 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_8365 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_pctlr
# __________________________________________________________________________________________________
# normalization_8366 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanR
# __________________________________________________________________________________________________
# normalization_8367 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_8368 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanF
# __________________________________________________________________________________________________
# normalization_8369 (Normalizati (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_8370 (Normalizati (None, 1)            3           loudness_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8371 (Normalizati (None, 1)            3           loudness_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_8372 (Normalizati (None, 1)            3           loudness_sma3_percentile20.0[0][0
# __________________________________________________________________________________________________
# normalization_8373 (Normalizati (None, 1)            3           loudness_sma3_percentile50.0[0][0
# __________________________________________________________________________________________________
# normalization_8374 (Normalizati (None, 1)            3           loudness_sma3_percentile80.0[0][0
# __________________________________________________________________________________________________
# normalization_8375 (Normalizati (None, 1)            3           loudness_sma3_pctlrange0-2[0][0]
# __________________________________________________________________________________________________
# normalization_8376 (Normalizati (None, 1)            3           loudness_sma3_meanRisingSlope[0][
# __________________________________________________________________________________________________
# normalization_8377 (Normalizati (None, 1)            3           loudness_sma3_stddevRisingSlope[0
# __________________________________________________________________________________________________
# normalization_8378 (Normalizati (None, 1)            3           loudness_sma3_meanFallingSlope[0]
# __________________________________________________________________________________________________
# normalization_8379 (Normalizati (None, 1)            3           loudness_sma3_stddevFallingSlope[
# __________________________________________________________________________________________________
# normalization_8380 (Normalizati (None, 1)            3           spectralFlux_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8381 (Normalizati (None, 1)            3           spectralFlux_sma3_stddevNorm[0][0
# __________________________________________________________________________________________________
# normalization_8382 (Normalizati (None, 1)            3           mfcc1_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8383 (Normalizati (None, 1)            3           mfcc1_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_8384 (Normalizati (None, 1)            3           mfcc2_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8385 (Normalizati (None, 1)            3           mfcc2_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_8386 (Normalizati (None, 1)            3           mfcc3_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8387 (Normalizati (None, 1)            3           mfcc3_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_8388 (Normalizati (None, 1)            3           mfcc4_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8389 (Normalizati (None, 1)            3           mfcc4_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_8390 (Normalizati (None, 1)            3           jitterLocal_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8391 (Normalizati (None, 1)            3           jitterLocal_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_8392 (Normalizati (None, 1)            3           shimmerLocaldB_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8393 (Normalizati (None, 1)            3           shimmerLocaldB_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_8394 (Normalizati (None, 1)            3           HNRdBACF_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8395 (Normalizati (None, 1)            3           HNRdBACF_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_8396 (Normalizati (None, 1)            3           logRelF0-H1-H2_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8397 (Normalizati (None, 1)            3           logRelF0-H1-H2_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_8398 (Normalizati (None, 1)            3           logRelF0-H1-A3_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8399 (Normalizati (None, 1)            3           logRelF0-H1-A3_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_8400 (Normalizati (None, 1)            3           F1frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8401 (Normalizati (None, 1)            3           F1frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_8402 (Normalizati (None, 1)            3           F1bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8403 (Normalizati (None, 1)            3           F1bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_8404 (Normalizati (None, 1)            3           F1amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_8405 (Normalizati (None, 1)            3           F1amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_8406 (Normalizati (None, 1)            3           F2frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8407 (Normalizati (None, 1)            3           F2frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_8408 (Normalizati (None, 1)            3           F2bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8409 (Normalizati (None, 1)            3           F2bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_8410 (Normalizati (None, 1)            3           F2amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_8411 (Normalizati (None, 1)            3           F2amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_8412 (Normalizati (None, 1)            3           F3frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8413 (Normalizati (None, 1)            3           F3frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_8414 (Normalizati (None, 1)            3           F3bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8415 (Normalizati (None, 1)            3           F3bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_8416 (Normalizati (None, 1)            3           F3amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_8417 (Normalizati (None, 1)            3           F3amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_8418 (Normalizati (None, 1)            3           alphaRatioV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8419 (Normalizati (None, 1)            3           alphaRatioV_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_8420 (Normalizati (None, 1)            3           hammarbergIndexV_sma3nz_amean[0][
# __________________________________________________________________________________________________
# normalization_8421 (Normalizati (None, 1)            3           hammarbergIndexV_sma3nz_stddevNor
# __________________________________________________________________________________________________
# normalization_8422 (Normalizati (None, 1)            3           slopeV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8423 (Normalizati (None, 1)            3           slopeV0-500_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_8424 (Normalizati (None, 1)            3           slopeV500-1500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8425 (Normalizati (None, 1)            3           slopeV500-1500_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_8426 (Normalizati (None, 1)            3           spectralFluxV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8427 (Normalizati (None, 1)            3           spectralFluxV_sma3nz_stddevNorm[0
# __________________________________________________________________________________________________
# normalization_8428 (Normalizati (None, 1)            3           mfcc1V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8429 (Normalizati (None, 1)            3           mfcc1V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_8430 (Normalizati (None, 1)            3           mfcc2V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8431 (Normalizati (None, 1)            3           mfcc2V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_8432 (Normalizati (None, 1)            3           mfcc3V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8433 (Normalizati (None, 1)            3           mfcc3V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_8434 (Normalizati (None, 1)            3           mfcc4V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8435 (Normalizati (None, 1)            3           mfcc4V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_8436 (Normalizati (None, 1)            3           alphaRatioUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8437 (Normalizati (None, 1)            3           hammarbergIndexUV_sma3nz_amean[0]
# __________________________________________________________________________________________________
# normalization_8438 (Normalizati (None, 1)            3           slopeUV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8439 (Normalizati (None, 1)            3           slopeUV500-1500_sma3nz_amean[0][0
# __________________________________________________________________________________________________
# normalization_8440 (Normalizati (None, 1)            3           spectralFluxUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_8441 (Normalizati (None, 1)            3           loudnessPeaksPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_8442 (Normalizati (None, 1)            3           VoicedSegmentsPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_8443 (Normalizati (None, 1)            3           MeanVoicedSegmentLengthSec[0][0]
# __________________________________________________________________________________________________
# normalization_8444 (Normalizati (None, 1)            3           StddevVoicedSegmentLengthSec[0][0
# __________________________________________________________________________________________________
# normalization_8445 (Normalizati (None, 1)            3           MeanUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_8446 (Normalizati (None, 1)            3           StddevUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_8447 (Normalizati (None, 1)            3           equivalentSoundLevel_dBp[0][0]
# __________________________________________________________________________________________________
# concatenate_95 (Concatenate)    (None, 88)           0           normalization_8360[0][0]
#                                                                  normalization_8361[0][0]
#                                                                  normalization_8362[0][0]
#                                                                  normalization_8363[0][0]
#                                                                  normalization_8364[0][0]
#                                                                  normalization_8365[0][0]
#                                                                  normalization_8366[0][0]
#                                                                  normalization_8367[0][0]
#                                                                  normalization_8368[0][0]
#                                                                  normalization_8369[0][0]
#                                                                  normalization_8370[0][0]
#                                                                  normalization_8371[0][0]
#                                                                  normalization_8372[0][0]
#                                                                  normalization_8373[0][0]
#                                                                  normalization_8374[0][0]
#                                                                  normalization_8375[0][0]
#                                                                  normalization_8376[0][0]
#                                                                  normalization_8377[0][0]
#                                                                  normalization_8378[0][0]
#                                                                  normalization_8379[0][0]
#                                                                  normalization_8380[0][0]
#                                                                  normalization_8381[0][0]
#                                                                  normalization_8382[0][0]
#                                                                  normalization_8383[0][0]
#                                                                  normalization_8384[0][0]
#                                                                  normalization_8385[0][0]
#                                                                  normalization_8386[0][0]
#                                                                  normalization_8387[0][0]
#                                                                  normalization_8388[0][0]
#                                                                  normalization_8389[0][0]
#                                                                  normalization_8390[0][0]
#                                                                  normalization_8391[0][0]
#                                                                  normalization_8392[0][0]
#                                                                  normalization_8393[0][0]
#                                                                  normalization_8394[0][0]
#                                                                  normalization_8395[0][0]
#                                                                  normalization_8396[0][0]
#                                                                  normalization_8397[0][0]
#                                                                  normalization_8398[0][0]
#                                                                  normalization_8399[0][0]
#                                                                  normalization_8400[0][0]
#                                                                  normalization_8401[0][0]
#                                                                  normalization_8402[0][0]
#                                                                  normalization_8403[0][0]
#                                                                  normalization_8404[0][0]
#                                                                  normalization_8405[0][0]
#                                                                  normalization_8406[0][0]
#                                                                  normalization_8407[0][0]
#                                                                  normalization_8408[0][0]
#                                                                  normalization_8409[0][0]
#                                                                  normalization_8410[0][0]
#                                                                  normalization_8411[0][0]
#                                                                  normalization_8412[0][0]
#                                                                  normalization_8413[0][0]
#                                                                  normalization_8414[0][0]
#                                                                  normalization_8415[0][0]
#                                                                  normalization_8416[0][0]
#                                                                  normalization_8417[0][0]
#                                                                  normalization_8418[0][0]
#                                                                  normalization_8419[0][0]
#                                                                  normalization_8420[0][0]
#                                                                  normalization_8421[0][0]
#                                                                  normalization_8422[0][0]
#                                                                  normalization_8423[0][0]
#                                                                  normalization_8424[0][0]
#                                                                  normalization_8425[0][0]
#                                                                  normalization_8426[0][0]
#                                                                  normalization_8427[0][0]
#                                                                  normalization_8428[0][0]
#                                                                  normalization_8429[0][0]
#                                                                  normalization_8430[0][0]
#                                                                  normalization_8431[0][0]
#                                                                  normalization_8432[0][0]
#                                                                  normalization_8433[0][0]
#                                                                  normalization_8434[0][0]
#                                                                  normalization_8435[0][0]
#                                                                  normalization_8436[0][0]
#                                                                  normalization_8437[0][0]
#                                                                  normalization_8438[0][0]
#                                                                  normalization_8439[0][0]
#                                                                  normalization_8440[0][0]
#                                                                  normalization_8441[0][0]
#                                                                  normalization_8442[0][0]
#                                                                  normalization_8443[0][0]
#                                                                  normalization_8444[0][0]
#                                                                  normalization_8445[0][0]
#                                                                  normalization_8446[0][0]
#                                                                  normalization_8447[0][0]
# __________________________________________________________________________________________________
# dense_284 (Dense)               (None, 128)          11392       concatenate_95[0][0]
# __________________________________________________________________________________________________
# dense_285 (Dense)               (None, 128)          16512       dense_284[0][0]
# __________________________________________________________________________________________________
# dense_286 (Dense)               (None, 128)          16512       dense_285[0][0]
# __________________________________________________________________________________________________
# dropout_95 (Dropout)            (None, 128)          0           dense_286[0][0]
# __________________________________________________________________________________________________
# dense_287 (Dense)               (None, 1)            129         dropout_95[0][0]
# ==================================================================================================
# Total params: 44,809
# Trainable params: 44,545
# Non-trainable params: 264
# __________________________________________________________________________________________________
# None

# %% [markdown]
# <a id='id5'></a>

# %%
def data_model(path, save_path, save_name_start = 'train', iter_num = 5, epoch_num =20, neurons = 32):
    """
    Function that creates datasets out of csv files and normalizes them using Keras layer preprocessing. Then a model is 
    created     and trained multiple times. Then it's metrics are saved and their summary is printed in the console.
    
    Parameters:
    path - filepath of the csv document with features
    save_path - directory where model metrics will be saved
    save_name_start - beginning of each saved file
    iter_num - number of Kfold splits
    epoch_num - number of epochs
    neurons - number of neurons on first dense layer
    
    Returns:
    df - Padnas DataFrame with best metrics from each cycle
    summary - model summary
    """
    try:
        makedirs(save_path)
    except:
        pass
    save_path = save_path+save_name_start
    file = path
    df = pd.read_csv(file)
    df.drop('Unnamed: 0', axis=1, inplace = True)
    base = list(range(0,int(len(df)/5))) #array of numbers equal to number of whole samples
    
    # Defining list to store best values
    best_loss = []
    best_acc = []
    best_loss_val = []
    best_acc_val = []
    batch_size = 20
    iterator = 0
    kfold = KFold(n_splits=iter_num, shuffle=True)
    
    for train_base, val_base in kfold.split(base):
        train = pd.DataFrame(load_subsample_data(train_base, df),columns=df.columns)
        val = pd.DataFrame(load_subsample_data(val_base, df),columns=df.columns)
        train_ds = df_to_dataset(train, batch_size=batch_size)
        column_list = train.columns[0:-1]
        all_inputs = []
        encoded_features = []
        count = 0
        for header in column_list:
            count += 1
            print('Processed %d column out of %d' % (count, len(column_list)), end="\r", flush=True)
            numeric_col = tf.keras.Input(shape=(1,), name=header)
            normalization_layer = get_normalization_layer(header, train_ds)
            encoded_numeric_col = normalization_layer(numeric_col)
            all_inputs.append(numeric_col)
            encoded_features.append(encoded_numeric_col)

        print("")
        # Build model
        all_features = tf.keras.layers.concatenate(encoded_features)
        x = tf.keras.layers.Dense(neurons, activation="relu")(all_features)
        x = tf.keras.layers.Dense(neurons, activation="relu")(x)
        x = tf.keras.layers.Dense(int(neurons/2), activation="relu")(x)
        x = tf.keras.layers.Dropout(0.4)(x)
        output = tf.keras.layers.Dense(1)(x)
        val_ds = df_to_dataset(val, shuffle=False, batch_size=batch_size)
        iterator += 1
        print('Training cycle %d out of %d' % (iterator, iter_num), end="\r", flush=True)
        model = tf.keras.Model(all_inputs, output)
        model.compile(optimizer='adam',
                      loss=tf.keras.losses.BinaryCrossentropy(),
                      metrics=["accuracy"])
        model.fit(train_ds, epochs=epoch_num, validation_data=val_ds, verbose=0)
        df2 = pd.DataFrame()
        for part in ['loss', 'accuracy', 'val_loss', 'val_accuracy']: 
            df2[part] = model.history.history[part]
        df2.index.names = ['Epoch']
        df2.to_csv(save_path+'_training'+str(iterator)+'.csv')

        # Save best values
        best_loss.append(max(model.history.history['loss']))
        best_acc.append(max(model.history.history['accuracy']))
        best_loss_val.append(max(model.history.history['val_loss']))
        best_acc_val.append(max(model.history.history['val_accuracy']))
        print("")
    
    # Post training
    summary = model.summary # Every model is the same so the summary can be called post training loop
    df = pd.DataFrame()
    df['Best_Loss'] = best_loss
    df['Best_Acc'] = best_acc
    df['Best_Loss_Val'] = best_loss_val
    df['Best_Acc_Val'] = best_acc_val
    df.index.names = ['Model_Num']
    df.to_csv(save_path+'_best'+'.csv')
    return df, summary

# %%
start_time_full = time.time()
for number in [32, 64, 128]:
    print('Model training: ')
    print('')
    print('---------------------------------------------------------------------------------------------------------------')
    print('')
    print('\t \t \t Processing layers ', str(number))
    print('')
    print('---------------------------------------------------------------------------------------------------------------')
    print('')
    start_time = time.time()
    df, summary = data_model('./csvs/eGeMAPS/ReadText_eGeMAPSv01b.csv',
                             './layer_test_train_outputs/id5/'+str(number)+'/', 
                             'Id1', iter_num=8, epoch_num=100, neurons=number)
    print('Elapsed time: ' , time.time() - start_time)

print('Full elapsed time: ' , time.time() - start_time_full)
print(summary())
# Out:
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  32
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  152.20969128608704
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  64
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  152.39160180091858
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  128
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  155.1062400341034
# Full elapsed time:  459.7085328102112
# Model: "functional_239"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# F0semitoneFrom27.5Hz_sma3nz_ame [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_pct [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile20.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile50.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile80.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_pctlrange0-2 (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanRisingSlope ( [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevRisingSlope [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanFallingSlope  [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevFallingSlop [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFlux_sma3_amean (InputL [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFlux_sma3_stddevNorm (I [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_amean (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_stddevNorm (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_amean ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_stddevN [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxV_sma3nz_amean (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxV_sma3nz_stddevNorm [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioUV_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexUV_sma3nz_amean  [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV0-500_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV500-1500_sma3nz_amean (I [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxUV_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# loudnessPeaksPerSec (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# VoicedSegmentsPerSec (InputLaye [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanVoicedSegmentLengthSec (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevVoicedSegmentLengthSec (I [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanUnvoicedSegmentLength (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevUnvoicedSegmentLength (In [(None, 1)]          0
# __________________________________________________________________________________________________
# equivalentSoundLevel_dBp (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# normalization_10472 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_amean
# __________________________________________________________________________________________________
# normalization_10473 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_10474 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_10475 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_10476 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_10477 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_pctlr
# __________________________________________________________________________________________________
# normalization_10478 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanR
# __________________________________________________________________________________________________
# normalization_10479 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_10480 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanF
# __________________________________________________________________________________________________
# normalization_10481 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_10482 (Normalizat (None, 1)            3           loudness_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10483 (Normalizat (None, 1)            3           loudness_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_10484 (Normalizat (None, 1)            3           loudness_sma3_percentile20.0[0][0
# __________________________________________________________________________________________________
# normalization_10485 (Normalizat (None, 1)            3           loudness_sma3_percentile50.0[0][0
# __________________________________________________________________________________________________
# normalization_10486 (Normalizat (None, 1)            3           loudness_sma3_percentile80.0[0][0
# __________________________________________________________________________________________________
# normalization_10487 (Normalizat (None, 1)            3           loudness_sma3_pctlrange0-2[0][0]
# __________________________________________________________________________________________________
# normalization_10488 (Normalizat (None, 1)            3           loudness_sma3_meanRisingSlope[0][
# __________________________________________________________________________________________________
# normalization_10489 (Normalizat (None, 1)            3           loudness_sma3_stddevRisingSlope[0
# __________________________________________________________________________________________________
# normalization_10490 (Normalizat (None, 1)            3           loudness_sma3_meanFallingSlope[0]
# __________________________________________________________________________________________________
# normalization_10491 (Normalizat (None, 1)            3           loudness_sma3_stddevFallingSlope[
# __________________________________________________________________________________________________
# normalization_10492 (Normalizat (None, 1)            3           spectralFlux_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10493 (Normalizat (None, 1)            3           spectralFlux_sma3_stddevNorm[0][0
# __________________________________________________________________________________________________
# normalization_10494 (Normalizat (None, 1)            3           mfcc1_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10495 (Normalizat (None, 1)            3           mfcc1_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_10496 (Normalizat (None, 1)            3           mfcc2_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10497 (Normalizat (None, 1)            3           mfcc2_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_10498 (Normalizat (None, 1)            3           mfcc3_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10499 (Normalizat (None, 1)            3           mfcc3_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_10500 (Normalizat (None, 1)            3           mfcc4_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10501 (Normalizat (None, 1)            3           mfcc4_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_10502 (Normalizat (None, 1)            3           jitterLocal_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10503 (Normalizat (None, 1)            3           jitterLocal_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_10504 (Normalizat (None, 1)            3           shimmerLocaldB_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10505 (Normalizat (None, 1)            3           shimmerLocaldB_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_10506 (Normalizat (None, 1)            3           HNRdBACF_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10507 (Normalizat (None, 1)            3           HNRdBACF_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_10508 (Normalizat (None, 1)            3           logRelF0-H1-H2_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10509 (Normalizat (None, 1)            3           logRelF0-H1-H2_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_10510 (Normalizat (None, 1)            3           logRelF0-H1-A3_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10511 (Normalizat (None, 1)            3           logRelF0-H1-A3_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_10512 (Normalizat (None, 1)            3           F1frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10513 (Normalizat (None, 1)            3           F1frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_10514 (Normalizat (None, 1)            3           F1bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10515 (Normalizat (None, 1)            3           F1bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_10516 (Normalizat (None, 1)            3           F1amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_10517 (Normalizat (None, 1)            3           F1amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_10518 (Normalizat (None, 1)            3           F2frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10519 (Normalizat (None, 1)            3           F2frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_10520 (Normalizat (None, 1)            3           F2bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10521 (Normalizat (None, 1)            3           F2bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_10522 (Normalizat (None, 1)            3           F2amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_10523 (Normalizat (None, 1)            3           F2amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_10524 (Normalizat (None, 1)            3           F3frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10525 (Normalizat (None, 1)            3           F3frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_10526 (Normalizat (None, 1)            3           F3bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10527 (Normalizat (None, 1)            3           F3bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_10528 (Normalizat (None, 1)            3           F3amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_10529 (Normalizat (None, 1)            3           F3amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_10530 (Normalizat (None, 1)            3           alphaRatioV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10531 (Normalizat (None, 1)            3           alphaRatioV_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_10532 (Normalizat (None, 1)            3           hammarbergIndexV_sma3nz_amean[0][
# __________________________________________________________________________________________________
# normalization_10533 (Normalizat (None, 1)            3           hammarbergIndexV_sma3nz_stddevNor
# __________________________________________________________________________________________________
# normalization_10534 (Normalizat (None, 1)            3           slopeV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10535 (Normalizat (None, 1)            3           slopeV0-500_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_10536 (Normalizat (None, 1)            3           slopeV500-1500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10537 (Normalizat (None, 1)            3           slopeV500-1500_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_10538 (Normalizat (None, 1)            3           spectralFluxV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10539 (Normalizat (None, 1)            3           spectralFluxV_sma3nz_stddevNorm[0
# __________________________________________________________________________________________________
# normalization_10540 (Normalizat (None, 1)            3           mfcc1V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10541 (Normalizat (None, 1)            3           mfcc1V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_10542 (Normalizat (None, 1)            3           mfcc2V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10543 (Normalizat (None, 1)            3           mfcc2V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_10544 (Normalizat (None, 1)            3           mfcc3V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10545 (Normalizat (None, 1)            3           mfcc3V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_10546 (Normalizat (None, 1)            3           mfcc4V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10547 (Normalizat (None, 1)            3           mfcc4V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_10548 (Normalizat (None, 1)            3           alphaRatioUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10549 (Normalizat (None, 1)            3           hammarbergIndexUV_sma3nz_amean[0]
# __________________________________________________________________________________________________
# normalization_10550 (Normalizat (None, 1)            3           slopeUV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10551 (Normalizat (None, 1)            3           slopeUV500-1500_sma3nz_amean[0][0
# __________________________________________________________________________________________________
# normalization_10552 (Normalizat (None, 1)            3           spectralFluxUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_10553 (Normalizat (None, 1)            3           loudnessPeaksPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_10554 (Normalizat (None, 1)            3           VoicedSegmentsPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_10555 (Normalizat (None, 1)            3           MeanVoicedSegmentLengthSec[0][0]
# __________________________________________________________________________________________________
# normalization_10556 (Normalizat (None, 1)            3           StddevVoicedSegmentLengthSec[0][0
# __________________________________________________________________________________________________
# normalization_10557 (Normalizat (None, 1)            3           MeanUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_10558 (Normalizat (None, 1)            3           StddevUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_10559 (Normalizat (None, 1)            3           equivalentSoundLevel_dBp[0][0]
# __________________________________________________________________________________________________
# concatenate_119 (Concatenate)   (None, 88)           0           normalization_10472[0][0]
#                                                                  normalization_10473[0][0]
#                                                                  normalization_10474[0][0]
#                                                                  normalization_10475[0][0]
#                                                                  normalization_10476[0][0]
#                                                                  normalization_10477[0][0]
#                                                                  normalization_10478[0][0]
#                                                                  normalization_10479[0][0]
#                                                                  normalization_10480[0][0]
#                                                                  normalization_10481[0][0]
#                                                                  normalization_10482[0][0]
#                                                                  normalization_10483[0][0]
#                                                                  normalization_10484[0][0]
#                                                                  normalization_10485[0][0]
#                                                                  normalization_10486[0][0]
#                                                                  normalization_10487[0][0]
#                                                                  normalization_10488[0][0]
#                                                                  normalization_10489[0][0]
#                                                                  normalization_10490[0][0]
#                                                                  normalization_10491[0][0]
#                                                                  normalization_10492[0][0]
#                                                                  normalization_10493[0][0]
#                                                                  normalization_10494[0][0]
#                                                                  normalization_10495[0][0]
#                                                                  normalization_10496[0][0]
#                                                                  normalization_10497[0][0]
#                                                                  normalization_10498[0][0]
#                                                                  normalization_10499[0][0]
#                                                                  normalization_10500[0][0]
#                                                                  normalization_10501[0][0]
#                                                                  normalization_10502[0][0]
#                                                                  normalization_10503[0][0]
#                                                                  normalization_10504[0][0]
#                                                                  normalization_10505[0][0]
#                                                                  normalization_10506[0][0]
#                                                                  normalization_10507[0][0]
#                                                                  normalization_10508[0][0]
#                                                                  normalization_10509[0][0]
#                                                                  normalization_10510[0][0]
#                                                                  normalization_10511[0][0]
#                                                                  normalization_10512[0][0]
#                                                                  normalization_10513[0][0]
#                                                                  normalization_10514[0][0]
#                                                                  normalization_10515[0][0]
#                                                                  normalization_10516[0][0]
#                                                                  normalization_10517[0][0]
#                                                                  normalization_10518[0][0]
#                                                                  normalization_10519[0][0]
#                                                                  normalization_10520[0][0]
#                                                                  normalization_10521[0][0]
#                                                                  normalization_10522[0][0]
#                                                                  normalization_10523[0][0]
#                                                                  normalization_10524[0][0]
#                                                                  normalization_10525[0][0]
#                                                                  normalization_10526[0][0]
#                                                                  normalization_10527[0][0]
#                                                                  normalization_10528[0][0]
#                                                                  normalization_10529[0][0]
#                                                                  normalization_10530[0][0]
#                                                                  normalization_10531[0][0]
#                                                                  normalization_10532[0][0]
#                                                                  normalization_10533[0][0]
#                                                                  normalization_10534[0][0]
#                                                                  normalization_10535[0][0]
#                                                                  normalization_10536[0][0]
#                                                                  normalization_10537[0][0]
#                                                                  normalization_10538[0][0]
#                                                                  normalization_10539[0][0]
#                                                                  normalization_10540[0][0]
#                                                                  normalization_10541[0][0]
#                                                                  normalization_10542[0][0]
#                                                                  normalization_10543[0][0]
#                                                                  normalization_10544[0][0]
#                                                                  normalization_10545[0][0]
#                                                                  normalization_10546[0][0]
#                                                                  normalization_10547[0][0]
#                                                                  normalization_10548[0][0]
#                                                                  normalization_10549[0][0]
#                                                                  normalization_10550[0][0]
#                                                                  normalization_10551[0][0]
#                                                                  normalization_10552[0][0]
#                                                                  normalization_10553[0][0]
#                                                                  normalization_10554[0][0]
#                                                                  normalization_10555[0][0]
#                                                                  normalization_10556[0][0]
#                                                                  normalization_10557[0][0]
#                                                                  normalization_10558[0][0]
#                                                                  normalization_10559[0][0]
# __________________________________________________________________________________________________
# dense_380 (Dense)               (None, 128)          11392       concatenate_119[0][0]
# __________________________________________________________________________________________________
# dense_381 (Dense)               (None, 128)          16512       dense_380[0][0]
# __________________________________________________________________________________________________
# dense_382 (Dense)               (None, 64)           8256        dense_381[0][0]
# __________________________________________________________________________________________________
# dropout_119 (Dropout)           (None, 64)           0           dense_382[0][0]
# __________________________________________________________________________________________________
# dense_383 (Dense)               (None, 1)            65          dropout_119[0][0]
# ==================================================================================================
# Total params: 36,489
# Trainable params: 36,225
# Non-trainable params: 264
# __________________________________________________________________________________________________
# None

# %% [markdown]
# <a id='id6'></a>

# %%
def data_model(path, save_path, save_name_start = 'train', iter_num = 5, epoch_num =20, neurons = 32):
    """
    Function that creates datasets out of csv files and normalizes them using Keras layer preprocessing. Then a model is 
    created     and trained multiple times. Then it's metrics are saved and their summary is printed in the console.
    
    Parameters:
    path - filepath of the csv document with features
    save_path - directory where model metrics will be saved
    save_name_start - beginning of each saved file
    iter_num - number of Kfold splits
    epoch_num - number of epochs
    neurons - number of neurons on first dense layer
    
    Returns:
    df - Padnas DataFrame with best metrics from each cycle
    summary - model summary
    """
    try:
        makedirs(save_path)
    except:
        pass
    save_path = save_path+save_name_start
    file = path
    df = pd.read_csv(file)
    df.drop('Unnamed: 0', axis=1, inplace = True)
    base = list(range(0,int(len(df)/5))) #array of numbers equal to number of whole samples
    
    # Defining list to store best values
    best_loss = []
    best_acc = []
    best_loss_val = []
    best_acc_val = []
    batch_size = 20
    iterator = 0
    kfold = KFold(n_splits=iter_num, shuffle=True)
    
    for train_base, val_base in kfold.split(base):
        train = pd.DataFrame(load_subsample_data(train_base, df),columns=df.columns)
        val = pd.DataFrame(load_subsample_data(val_base, df),columns=df.columns)
        train_ds = df_to_dataset(train, batch_size=batch_size)
        column_list = train.columns[0:-1]
        all_inputs = []
        encoded_features = []
        count = 0
        for header in column_list:
            count += 1
            print('Processed %d column out of %d' % (count, len(column_list)), end="\r", flush=True)
            numeric_col = tf.keras.Input(shape=(1,), name=header)
            normalization_layer = get_normalization_layer(header, train_ds)
            encoded_numeric_col = normalization_layer(numeric_col)
            all_inputs.append(numeric_col)
            encoded_features.append(encoded_numeric_col)

        print("")
        # Build model
        all_features = tf.keras.layers.concatenate(encoded_features)
        x = tf.keras.layers.Dense(neurons, activation="relu")(all_features)
        x = tf.keras.layers.Dense(int(neurons/2), activation="relu")(x)
        x = tf.keras.layers.Dense(int(neurons/2), activation="relu")(x)
        x = tf.keras.layers.Dropout(0.4)(x)
        output = tf.keras.layers.Dense(1)(x)
        val_ds = df_to_dataset(val, shuffle=False, batch_size=batch_size)
        iterator += 1
        print('Training cycle %d out of %d' % (iterator, iter_num), end="\r", flush=True)
        model = tf.keras.Model(all_inputs, output)
        model.compile(optimizer='adam',
                      loss=tf.keras.losses.BinaryCrossentropy(),
                      metrics=["accuracy"])
        model.fit(train_ds, epochs=epoch_num, validation_data=val_ds, verbose=0)
        df2 = pd.DataFrame()
        for part in ['loss', 'accuracy', 'val_loss', 'val_accuracy']: 
            df2[part] = model.history.history[part]
        df2.index.names = ['Epoch']
        df2.to_csv(save_path+'_training'+str(iterator)+'.csv')

        # Save best values
        best_loss.append(max(model.history.history['loss']))
        best_acc.append(max(model.history.history['accuracy']))
        best_loss_val.append(max(model.history.history['val_loss']))
        best_acc_val.append(max(model.history.history['val_accuracy']))
        print("")
    
    # Post training
    summary = model.summary # Every model is the same so the summary can be called post training loop
    df = pd.DataFrame()
    df['Best_Loss'] = best_loss
    df['Best_Acc'] = best_acc
    df['Best_Loss_Val'] = best_loss_val
    df['Best_Acc_Val'] = best_acc_val
    df.index.names = ['Model_Num']
    df.to_csv(save_path+'_best'+'.csv')
    return df, summary

# %%
start_time_full = time.time()
for number in [32, 64, 128]:
    print('Model training: ')
    print('')
    print('---------------------------------------------------------------------------------------------------------------')
    print('')
    print('\t \t \t Processing layers ', str(number))
    print('')
    print('---------------------------------------------------------------------------------------------------------------')
    print('')
    start_time = time.time()
    df, summary = data_model('./csvs/eGeMAPS/ReadText_eGeMAPSv01b.csv',
                             './layer_test_train_outputs/id6/'+str(number)+'/', 
                             'Id1', iter_num=8, epoch_num=100, neurons=number)
    print('Elapsed time: ' , time.time() - start_time)

print('Full elapsed time: ' , time.time() - start_time_full)
print(summary())
# Out:
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  32
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  151.0690131187439
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  64
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  153.1948573589325
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  128
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  150.56487441062927
# Full elapsed time:  454.82874488830566
# Model: "functional_287"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# F0semitoneFrom27.5Hz_sma3nz_ame [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_pct [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile20.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile50.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile80.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_pctlrange0-2 (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanRisingSlope ( [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevRisingSlope [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanFallingSlope  [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevFallingSlop [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFlux_sma3_amean (InputL [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFlux_sma3_stddevNorm (I [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_amean (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_stddevNorm (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_amean ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_stddevN [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxV_sma3nz_amean (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxV_sma3nz_stddevNorm [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioUV_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexUV_sma3nz_amean  [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV0-500_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV500-1500_sma3nz_amean (I [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxUV_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# loudnessPeaksPerSec (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# VoicedSegmentsPerSec (InputLaye [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanVoicedSegmentLengthSec (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevVoicedSegmentLengthSec (I [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanUnvoicedSegmentLength (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevUnvoicedSegmentLength (In [(None, 1)]          0
# __________________________________________________________________________________________________
# equivalentSoundLevel_dBp (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# normalization_12584 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_amean
# __________________________________________________________________________________________________
# normalization_12585 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_12586 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_12587 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_12588 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_12589 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_pctlr
# __________________________________________________________________________________________________
# normalization_12590 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanR
# __________________________________________________________________________________________________
# normalization_12591 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_12592 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanF
# __________________________________________________________________________________________________
# normalization_12593 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_12594 (Normalizat (None, 1)            3           loudness_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12595 (Normalizat (None, 1)            3           loudness_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_12596 (Normalizat (None, 1)            3           loudness_sma3_percentile20.0[0][0
# __________________________________________________________________________________________________
# normalization_12597 (Normalizat (None, 1)            3           loudness_sma3_percentile50.0[0][0
# __________________________________________________________________________________________________
# normalization_12598 (Normalizat (None, 1)            3           loudness_sma3_percentile80.0[0][0
# __________________________________________________________________________________________________
# normalization_12599 (Normalizat (None, 1)            3           loudness_sma3_pctlrange0-2[0][0]
# __________________________________________________________________________________________________
# normalization_12600 (Normalizat (None, 1)            3           loudness_sma3_meanRisingSlope[0][
# __________________________________________________________________________________________________
# normalization_12601 (Normalizat (None, 1)            3           loudness_sma3_stddevRisingSlope[0
# __________________________________________________________________________________________________
# normalization_12602 (Normalizat (None, 1)            3           loudness_sma3_meanFallingSlope[0]
# __________________________________________________________________________________________________
# normalization_12603 (Normalizat (None, 1)            3           loudness_sma3_stddevFallingSlope[
# __________________________________________________________________________________________________
# normalization_12604 (Normalizat (None, 1)            3           spectralFlux_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12605 (Normalizat (None, 1)            3           spectralFlux_sma3_stddevNorm[0][0
# __________________________________________________________________________________________________
# normalization_12606 (Normalizat (None, 1)            3           mfcc1_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12607 (Normalizat (None, 1)            3           mfcc1_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_12608 (Normalizat (None, 1)            3           mfcc2_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12609 (Normalizat (None, 1)            3           mfcc2_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_12610 (Normalizat (None, 1)            3           mfcc3_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12611 (Normalizat (None, 1)            3           mfcc3_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_12612 (Normalizat (None, 1)            3           mfcc4_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12613 (Normalizat (None, 1)            3           mfcc4_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_12614 (Normalizat (None, 1)            3           jitterLocal_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12615 (Normalizat (None, 1)            3           jitterLocal_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_12616 (Normalizat (None, 1)            3           shimmerLocaldB_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12617 (Normalizat (None, 1)            3           shimmerLocaldB_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_12618 (Normalizat (None, 1)            3           HNRdBACF_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12619 (Normalizat (None, 1)            3           HNRdBACF_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_12620 (Normalizat (None, 1)            3           logRelF0-H1-H2_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12621 (Normalizat (None, 1)            3           logRelF0-H1-H2_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_12622 (Normalizat (None, 1)            3           logRelF0-H1-A3_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12623 (Normalizat (None, 1)            3           logRelF0-H1-A3_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_12624 (Normalizat (None, 1)            3           F1frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12625 (Normalizat (None, 1)            3           F1frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_12626 (Normalizat (None, 1)            3           F1bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12627 (Normalizat (None, 1)            3           F1bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_12628 (Normalizat (None, 1)            3           F1amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_12629 (Normalizat (None, 1)            3           F1amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_12630 (Normalizat (None, 1)            3           F2frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12631 (Normalizat (None, 1)            3           F2frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_12632 (Normalizat (None, 1)            3           F2bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12633 (Normalizat (None, 1)            3           F2bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_12634 (Normalizat (None, 1)            3           F2amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_12635 (Normalizat (None, 1)            3           F2amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_12636 (Normalizat (None, 1)            3           F3frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12637 (Normalizat (None, 1)            3           F3frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_12638 (Normalizat (None, 1)            3           F3bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12639 (Normalizat (None, 1)            3           F3bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_12640 (Normalizat (None, 1)            3           F3amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_12641 (Normalizat (None, 1)            3           F3amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_12642 (Normalizat (None, 1)            3           alphaRatioV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12643 (Normalizat (None, 1)            3           alphaRatioV_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_12644 (Normalizat (None, 1)            3           hammarbergIndexV_sma3nz_amean[0][
# __________________________________________________________________________________________________
# normalization_12645 (Normalizat (None, 1)            3           hammarbergIndexV_sma3nz_stddevNor
# __________________________________________________________________________________________________
# normalization_12646 (Normalizat (None, 1)            3           slopeV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12647 (Normalizat (None, 1)            3           slopeV0-500_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_12648 (Normalizat (None, 1)            3           slopeV500-1500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12649 (Normalizat (None, 1)            3           slopeV500-1500_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_12650 (Normalizat (None, 1)            3           spectralFluxV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12651 (Normalizat (None, 1)            3           spectralFluxV_sma3nz_stddevNorm[0
# __________________________________________________________________________________________________
# normalization_12652 (Normalizat (None, 1)            3           mfcc1V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12653 (Normalizat (None, 1)            3           mfcc1V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_12654 (Normalizat (None, 1)            3           mfcc2V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12655 (Normalizat (None, 1)            3           mfcc2V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_12656 (Normalizat (None, 1)            3           mfcc3V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12657 (Normalizat (None, 1)            3           mfcc3V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_12658 (Normalizat (None, 1)            3           mfcc4V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12659 (Normalizat (None, 1)            3           mfcc4V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_12660 (Normalizat (None, 1)            3           alphaRatioUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12661 (Normalizat (None, 1)            3           hammarbergIndexUV_sma3nz_amean[0]
# __________________________________________________________________________________________________
# normalization_12662 (Normalizat (None, 1)            3           slopeUV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12663 (Normalizat (None, 1)            3           slopeUV500-1500_sma3nz_amean[0][0
# __________________________________________________________________________________________________
# normalization_12664 (Normalizat (None, 1)            3           spectralFluxUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_12665 (Normalizat (None, 1)            3           loudnessPeaksPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_12666 (Normalizat (None, 1)            3           VoicedSegmentsPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_12667 (Normalizat (None, 1)            3           MeanVoicedSegmentLengthSec[0][0]
# __________________________________________________________________________________________________
# normalization_12668 (Normalizat (None, 1)            3           StddevVoicedSegmentLengthSec[0][0
# __________________________________________________________________________________________________
# normalization_12669 (Normalizat (None, 1)            3           MeanUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_12670 (Normalizat (None, 1)            3           StddevUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_12671 (Normalizat (None, 1)            3           equivalentSoundLevel_dBp[0][0]
# __________________________________________________________________________________________________
# concatenate_143 (Concatenate)   (None, 88)           0           normalization_12584[0][0]
#                                                                  normalization_12585[0][0]
#                                                                  normalization_12586[0][0]
#                                                                  normalization_12587[0][0]
#                                                                  normalization_12588[0][0]
#                                                                  normalization_12589[0][0]
#                                                                  normalization_12590[0][0]
#                                                                  normalization_12591[0][0]
#                                                                  normalization_12592[0][0]
#                                                                  normalization_12593[0][0]
#                                                                  normalization_12594[0][0]
#                                                                  normalization_12595[0][0]
#                                                                  normalization_12596[0][0]
#                                                                  normalization_12597[0][0]
#                                                                  normalization_12598[0][0]
#                                                                  normalization_12599[0][0]
#                                                                  normalization_12600[0][0]
#                                                                  normalization_12601[0][0]
#                                                                  normalization_12602[0][0]
#                                                                  normalization_12603[0][0]
#                                                                  normalization_12604[0][0]
#                                                                  normalization_12605[0][0]
#                                                                  normalization_12606[0][0]
#                                                                  normalization_12607[0][0]
#                                                                  normalization_12608[0][0]
#                                                                  normalization_12609[0][0]
#                                                                  normalization_12610[0][0]
#                                                                  normalization_12611[0][0]
#                                                                  normalization_12612[0][0]
#                                                                  normalization_12613[0][0]
#                                                                  normalization_12614[0][0]
#                                                                  normalization_12615[0][0]
#                                                                  normalization_12616[0][0]
#                                                                  normalization_12617[0][0]
#                                                                  normalization_12618[0][0]
#                                                                  normalization_12619[0][0]
#                                                                  normalization_12620[0][0]
#                                                                  normalization_12621[0][0]
#                                                                  normalization_12622[0][0]
#                                                                  normalization_12623[0][0]
#                                                                  normalization_12624[0][0]
#                                                                  normalization_12625[0][0]
#                                                                  normalization_12626[0][0]
#                                                                  normalization_12627[0][0]
#                                                                  normalization_12628[0][0]
#                                                                  normalization_12629[0][0]
#                                                                  normalization_12630[0][0]
#                                                                  normalization_12631[0][0]
#                                                                  normalization_12632[0][0]
#                                                                  normalization_12633[0][0]
#                                                                  normalization_12634[0][0]
#                                                                  normalization_12635[0][0]
#                                                                  normalization_12636[0][0]
#                                                                  normalization_12637[0][0]
#                                                                  normalization_12638[0][0]
#                                                                  normalization_12639[0][0]
#                                                                  normalization_12640[0][0]
#                                                                  normalization_12641[0][0]
#                                                                  normalization_12642[0][0]
#                                                                  normalization_12643[0][0]
#                                                                  normalization_12644[0][0]
#                                                                  normalization_12645[0][0]
#                                                                  normalization_12646[0][0]
#                                                                  normalization_12647[0][0]
#                                                                  normalization_12648[0][0]
#                                                                  normalization_12649[0][0]
#                                                                  normalization_12650[0][0]
#                                                                  normalization_12651[0][0]
#                                                                  normalization_12652[0][0]
#                                                                  normalization_12653[0][0]
#                                                                  normalization_12654[0][0]
#                                                                  normalization_12655[0][0]
#                                                                  normalization_12656[0][0]
#                                                                  normalization_12657[0][0]
#                                                                  normalization_12658[0][0]
#                                                                  normalization_12659[0][0]
#                                                                  normalization_12660[0][0]
#                                                                  normalization_12661[0][0]
#                                                                  normalization_12662[0][0]
#                                                                  normalization_12663[0][0]
#                                                                  normalization_12664[0][0]
#                                                                  normalization_12665[0][0]
#                                                                  normalization_12666[0][0]
#                                                                  normalization_12667[0][0]
#                                                                  normalization_12668[0][0]
#                                                                  normalization_12669[0][0]
#                                                                  normalization_12670[0][0]
#                                                                  normalization_12671[0][0]
# __________________________________________________________________________________________________
# dense_476 (Dense)               (None, 128)          11392       concatenate_143[0][0]
# __________________________________________________________________________________________________
# dense_477 (Dense)               (None, 64)           8256        dense_476[0][0]
# __________________________________________________________________________________________________
# dense_478 (Dense)               (None, 64)           4160        dense_477[0][0]
# __________________________________________________________________________________________________
# dropout_143 (Dropout)           (None, 64)           0           dense_478[0][0]
# __________________________________________________________________________________________________
# dense_479 (Dense)               (None, 1)            65          dropout_143[0][0]
# ==================================================================================================
# Total params: 24,137
# Trainable params: 23,873
# Non-trainable params: 264
# __________________________________________________________________________________________________
# None

# %% [markdown]
# <a id='id7'></a>

# %%
def data_model(path, save_path, save_name_start = 'train', iter_num = 5, epoch_num =20, neurons = 32):
    """
    Function that creates datasets out of csv files and normalizes them using Keras layer preprocessing. Then a model is 
    created     and trained multiple times. Then it's metrics are saved and their summary is printed in the console.
    
    Parameters:
    path - filepath of the csv document with features
    save_path - directory where model metrics will be saved
    save_name_start - beginning of each saved file
    iter_num - number of Kfold splits
    epoch_num - number of epochs
    neurons - number of neurons on first dense layer
    
    Returns:
    df - Padnas DataFrame with best metrics from each cycle
    summary - model summary
    """
    try:
        makedirs(save_path)
    except:
        pass
    save_path = save_path+save_name_start
    file = path
    df = pd.read_csv(file)
    df.drop('Unnamed: 0', axis=1, inplace = True)
    base = list(range(0,int(len(df)/5))) #array of numbers equal to number of whole samples
    
    # Defining list to store best values
    best_loss = []
    best_acc = []
    best_loss_val = []
    best_acc_val = []
    batch_size = 20
    iterator = 0
    kfold = KFold(n_splits=iter_num, shuffle=True)
    
    for train_base, val_base in kfold.split(base):
        train = pd.DataFrame(load_subsample_data(train_base, df),columns=df.columns)
        val = pd.DataFrame(load_subsample_data(val_base, df),columns=df.columns)
        train_ds = df_to_dataset(train, batch_size=batch_size)
        column_list = train.columns[0:-1]
        all_inputs = []
        encoded_features = []
        count = 0
        for header in column_list:
            count += 1
            print('Processed %d column out of %d' % (count, len(column_list)), end="\r", flush=True)
            numeric_col = tf.keras.Input(shape=(1,), name=header)
            normalization_layer = get_normalization_layer(header, train_ds)
            encoded_numeric_col = normalization_layer(numeric_col)
            all_inputs.append(numeric_col)
            encoded_features.append(encoded_numeric_col)

        print("")
        # Build model
        all_features = tf.keras.layers.concatenate(encoded_features)
        x = tf.keras.layers.Dense(neurons, activation="relu")(all_features)
        x = tf.keras.layers.Dense(int(neurons/2), activation="relu")(x)
        x = tf.keras.layers.Dense(int(neurons/4), activation="relu")(x)
        x = tf.keras.layers.Dropout(0.4)(x)
        output = tf.keras.layers.Dense(1)(x)
        val_ds = df_to_dataset(val, shuffle=False, batch_size=batch_size)
        iterator += 1
        print('Training cycle %d out of %d' % (iterator, iter_num), end="\r", flush=True)
        model = tf.keras.Model(all_inputs, output)
        model.compile(optimizer='adam',
                      loss=tf.keras.losses.BinaryCrossentropy(),
                      metrics=["accuracy"])
        model.fit(train_ds, epochs=epoch_num, validation_data=val_ds, verbose=0)
        df2 = pd.DataFrame()
        for part in ['loss', 'accuracy', 'val_loss', 'val_accuracy']: 
            df2[part] = model.history.history[part]
        df2.index.names = ['Epoch']
        df2.to_csv(save_path+'_training'+str(iterator)+'.csv')

        # Save best values
        best_loss.append(max(model.history.history['loss']))
        best_acc.append(max(model.history.history['accuracy']))
        best_loss_val.append(max(model.history.history['val_loss']))
        best_acc_val.append(max(model.history.history['val_accuracy']))
        print("")
    
    # Post training
    summary = model.summary # Every model is the same so the summary can be called post training loop
    df = pd.DataFrame()
    df['Best_Loss'] = best_loss
    df['Best_Acc'] = best_acc
    df['Best_Loss_Val'] = best_loss_val
    df['Best_Acc_Val'] = best_acc_val
    df.index.names = ['Model_Num']
    df.to_csv(save_path+'_best'+'.csv')
    return df, summary

# %%
start_time_full = time.time()
for number in [32, 64, 128]:
    print('Model training: ')
    print('')
    print('---------------------------------------------------------------------------------------------------------------')
    print('')
    print('\t \t \t Processing layers ', str(number))
    print('')
    print('---------------------------------------------------------------------------------------------------------------')
    print('')
    start_time = time.time()
    df, summary = data_model('./csvs/eGeMAPS/ReadText_eGeMAPSv01b.csv',
                             './layer_test_train_outputs/id7/'+str(number)+'/', 
                             'Id1', iter_num=8, epoch_num=100, neurons=number)
    print('Elapsed time: ' , time.time() - start_time)

print('Full elapsed time: ' , time.time() - start_time_full)
print(summary())
# Out:
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  32
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  152.8968312740326
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  64
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  153.44792819023132
# Model training:
#
# ---------------------------------------------------------------------------------------------------------------
#
# 	 	 	 Processing layers  128
#
# ---------------------------------------------------------------------------------------------------------------
#
# Processed 88 column out of 88
# Training cycle 1 out of 8
# Processed 88 column out of 88
# Training cycle 2 out of 8
# Processed 88 column out of 88
# Training cycle 3 out of 8
# Processed 88 column out of 88
# Training cycle 4 out of 8
# Processed 88 column out of 88
# Training cycle 5 out of 8
# Processed 88 column out of 88
# Training cycle 6 out of 8
# Processed 88 column out of 88
# Training cycle 7 out of 8
# Processed 88 column out of 88
# Training cycle 8 out of 8
# Elapsed time:  151.17491579055786
# Full elapsed time:  457.5196752548218
# Model: "functional_335"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# F0semitoneFrom27.5Hz_sma3nz_ame [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_per [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_pct [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_mea [(None, 1)]          0
# __________________________________________________________________________________________________
# F0semitoneFrom27.5Hz_sma3nz_std [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile20.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile50.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_percentile80.0 (I [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_pctlrange0-2 (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanRisingSlope ( [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevRisingSlope [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_meanFallingSlope  [(None, 1)]          0
# __________________________________________________________________________________________________
# loudness_sma3_stddevFallingSlop [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFlux_sma3_amean (InputL [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFlux_sma3_stddevNorm (I [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4_sma3_amean (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4_sma3_stddevNorm (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# jitterLocal_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# shimmerLocaldB_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_amean (InputLay [(None, 1)]          0
# __________________________________________________________________________________________________
# HNRdBACF_sma3nz_stddevNorm (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-H2_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# logRelF0-H1-A3_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F1bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F1amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F2bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F2amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3frequency_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3bandwidth_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# F3bandwidth_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_amea [(None, 1)]          0
# __________________________________________________________________________________________________
# F3amplitudeLogRelF0_sma3nz_stdd [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioV_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_amean ( [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexV_sma3nz_stddevN [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_amean (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV0-500_sma3nz_stddevNorm ( [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeV500-1500_sma3nz_stddevNor [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxV_sma3nz_amean (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxV_sma3nz_stddevNorm [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc1V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc2V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc3V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4V_sma3nz_amean (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# mfcc4V_sma3nz_stddevNorm (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# alphaRatioUV_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# hammarbergIndexUV_sma3nz_amean  [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV0-500_sma3nz_amean (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# slopeUV500-1500_sma3nz_amean (I [(None, 1)]          0
# __________________________________________________________________________________________________
# spectralFluxUV_sma3nz_amean (In [(None, 1)]          0
# __________________________________________________________________________________________________
# loudnessPeaksPerSec (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# VoicedSegmentsPerSec (InputLaye [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanVoicedSegmentLengthSec (Inp [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevVoicedSegmentLengthSec (I [(None, 1)]          0
# __________________________________________________________________________________________________
# MeanUnvoicedSegmentLength (Inpu [(None, 1)]          0
# __________________________________________________________________________________________________
# StddevUnvoicedSegmentLength (In [(None, 1)]          0
# __________________________________________________________________________________________________
# equivalentSoundLevel_dBp (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# normalization_14696 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_amean
# __________________________________________________________________________________________________
# normalization_14697 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_14698 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_14699 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_14700 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_perce
# __________________________________________________________________________________________________
# normalization_14701 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_pctlr
# __________________________________________________________________________________________________
# normalization_14702 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanR
# __________________________________________________________________________________________________
# normalization_14703 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_14704 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_meanF
# __________________________________________________________________________________________________
# normalization_14705 (Normalizat (None, 1)            3           F0semitoneFrom27.5Hz_sma3nz_stdde
# __________________________________________________________________________________________________
# normalization_14706 (Normalizat (None, 1)            3           loudness_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14707 (Normalizat (None, 1)            3           loudness_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_14708 (Normalizat (None, 1)            3           loudness_sma3_percentile20.0[0][0
# __________________________________________________________________________________________________
# normalization_14709 (Normalizat (None, 1)            3           loudness_sma3_percentile50.0[0][0
# __________________________________________________________________________________________________
# normalization_14710 (Normalizat (None, 1)            3           loudness_sma3_percentile80.0[0][0
# __________________________________________________________________________________________________
# normalization_14711 (Normalizat (None, 1)            3           loudness_sma3_pctlrange0-2[0][0]
# __________________________________________________________________________________________________
# normalization_14712 (Normalizat (None, 1)            3           loudness_sma3_meanRisingSlope[0][
# __________________________________________________________________________________________________
# normalization_14713 (Normalizat (None, 1)            3           loudness_sma3_stddevRisingSlope[0
# __________________________________________________________________________________________________
# normalization_14714 (Normalizat (None, 1)            3           loudness_sma3_meanFallingSlope[0]
# __________________________________________________________________________________________________
# normalization_14715 (Normalizat (None, 1)            3           loudness_sma3_stddevFallingSlope[
# __________________________________________________________________________________________________
# normalization_14716 (Normalizat (None, 1)            3           spectralFlux_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14717 (Normalizat (None, 1)            3           spectralFlux_sma3_stddevNorm[0][0
# __________________________________________________________________________________________________
# normalization_14718 (Normalizat (None, 1)            3           mfcc1_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14719 (Normalizat (None, 1)            3           mfcc1_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_14720 (Normalizat (None, 1)            3           mfcc2_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14721 (Normalizat (None, 1)            3           mfcc2_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_14722 (Normalizat (None, 1)            3           mfcc3_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14723 (Normalizat (None, 1)            3           mfcc3_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_14724 (Normalizat (None, 1)            3           mfcc4_sma3_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14725 (Normalizat (None, 1)            3           mfcc4_sma3_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_14726 (Normalizat (None, 1)            3           jitterLocal_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14727 (Normalizat (None, 1)            3           jitterLocal_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_14728 (Normalizat (None, 1)            3           shimmerLocaldB_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14729 (Normalizat (None, 1)            3           shimmerLocaldB_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_14730 (Normalizat (None, 1)            3           HNRdBACF_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14731 (Normalizat (None, 1)            3           HNRdBACF_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_14732 (Normalizat (None, 1)            3           logRelF0-H1-H2_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14733 (Normalizat (None, 1)            3           logRelF0-H1-H2_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_14734 (Normalizat (None, 1)            3           logRelF0-H1-A3_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14735 (Normalizat (None, 1)            3           logRelF0-H1-A3_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_14736 (Normalizat (None, 1)            3           F1frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14737 (Normalizat (None, 1)            3           F1frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_14738 (Normalizat (None, 1)            3           F1bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14739 (Normalizat (None, 1)            3           F1bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_14740 (Normalizat (None, 1)            3           F1amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_14741 (Normalizat (None, 1)            3           F1amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_14742 (Normalizat (None, 1)            3           F2frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14743 (Normalizat (None, 1)            3           F2frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_14744 (Normalizat (None, 1)            3           F2bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14745 (Normalizat (None, 1)            3           F2bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_14746 (Normalizat (None, 1)            3           F2amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_14747 (Normalizat (None, 1)            3           F2amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_14748 (Normalizat (None, 1)            3           F3frequency_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14749 (Normalizat (None, 1)            3           F3frequency_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_14750 (Normalizat (None, 1)            3           F3bandwidth_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14751 (Normalizat (None, 1)            3           F3bandwidth_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_14752 (Normalizat (None, 1)            3           F3amplitudeLogRelF0_sma3nz_amean[
# __________________________________________________________________________________________________
# normalization_14753 (Normalizat (None, 1)            3           F3amplitudeLogRelF0_sma3nz_stddev
# __________________________________________________________________________________________________
# normalization_14754 (Normalizat (None, 1)            3           alphaRatioV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14755 (Normalizat (None, 1)            3           alphaRatioV_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_14756 (Normalizat (None, 1)            3           hammarbergIndexV_sma3nz_amean[0][
# __________________________________________________________________________________________________
# normalization_14757 (Normalizat (None, 1)            3           hammarbergIndexV_sma3nz_stddevNor
# __________________________________________________________________________________________________
# normalization_14758 (Normalizat (None, 1)            3           slopeV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14759 (Normalizat (None, 1)            3           slopeV0-500_sma3nz_stddevNorm[0][
# __________________________________________________________________________________________________
# normalization_14760 (Normalizat (None, 1)            3           slopeV500-1500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14761 (Normalizat (None, 1)            3           slopeV500-1500_sma3nz_stddevNorm[
# __________________________________________________________________________________________________
# normalization_14762 (Normalizat (None, 1)            3           spectralFluxV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14763 (Normalizat (None, 1)            3           spectralFluxV_sma3nz_stddevNorm[0
# __________________________________________________________________________________________________
# normalization_14764 (Normalizat (None, 1)            3           mfcc1V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14765 (Normalizat (None, 1)            3           mfcc1V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_14766 (Normalizat (None, 1)            3           mfcc2V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14767 (Normalizat (None, 1)            3           mfcc2V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_14768 (Normalizat (None, 1)            3           mfcc3V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14769 (Normalizat (None, 1)            3           mfcc3V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_14770 (Normalizat (None, 1)            3           mfcc4V_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14771 (Normalizat (None, 1)            3           mfcc4V_sma3nz_stddevNorm[0][0]
# __________________________________________________________________________________________________
# normalization_14772 (Normalizat (None, 1)            3           alphaRatioUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14773 (Normalizat (None, 1)            3           hammarbergIndexUV_sma3nz_amean[0]
# __________________________________________________________________________________________________
# normalization_14774 (Normalizat (None, 1)            3           slopeUV0-500_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14775 (Normalizat (None, 1)            3           slopeUV500-1500_sma3nz_amean[0][0
# __________________________________________________________________________________________________
# normalization_14776 (Normalizat (None, 1)            3           spectralFluxUV_sma3nz_amean[0][0]
# __________________________________________________________________________________________________
# normalization_14777 (Normalizat (None, 1)            3           loudnessPeaksPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_14778 (Normalizat (None, 1)            3           VoicedSegmentsPerSec[0][0]
# __________________________________________________________________________________________________
# normalization_14779 (Normalizat (None, 1)            3           MeanVoicedSegmentLengthSec[0][0]
# __________________________________________________________________________________________________
# normalization_14780 (Normalizat (None, 1)            3           StddevVoicedSegmentLengthSec[0][0
# __________________________________________________________________________________________________
# normalization_14781 (Normalizat (None, 1)            3           MeanUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_14782 (Normalizat (None, 1)            3           StddevUnvoicedSegmentLength[0][0]
# __________________________________________________________________________________________________
# normalization_14783 (Normalizat (None, 1)            3           equivalentSoundLevel_dBp[0][0]
# __________________________________________________________________________________________________
# concatenate_167 (Concatenate)   (None, 88)           0           normalization_14696[0][0]
#                                                                  normalization_14697[0][0]
#                                                                  normalization_14698[0][0]
#                                                                  normalization_14699[0][0]
#                                                                  normalization_14700[0][0]
#                                                                  normalization_14701[0][0]
#                                                                  normalization_14702[0][0]
#                                                                  normalization_14703[0][0]
#                                                                  normalization_14704[0][0]
#                                                                  normalization_14705[0][0]
#                                                                  normalization_14706[0][0]
#                                                                  normalization_14707[0][0]
#                                                                  normalization_14708[0][0]
#                                                                  normalization_14709[0][0]
#                                                                  normalization_14710[0][0]
#                                                                  normalization_14711[0][0]
#                                                                  normalization_14712[0][0]
#                                                                  normalization_14713[0][0]
#                                                                  normalization_14714[0][0]
#                                                                  normalization_14715[0][0]
#                                                                  normalization_14716[0][0]
#                                                                  normalization_14717[0][0]
#                                                                  normalization_14718[0][0]
#                                                                  normalization_14719[0][0]
#                                                                  normalization_14720[0][0]
#                                                                  normalization_14721[0][0]
#                                                                  normalization_14722[0][0]
#                                                                  normalization_14723[0][0]
#                                                                  normalization_14724[0][0]
#                                                                  normalization_14725[0][0]
#                                                                  normalization_14726[0][0]
#                                                                  normalization_14727[0][0]
#                                                                  normalization_14728[0][0]
#                                                                  normalization_14729[0][0]
#                                                                  normalization_14730[0][0]
#                                                                  normalization_14731[0][0]
#                                                                  normalization_14732[0][0]
#                                                                  normalization_14733[0][0]
#                                                                  normalization_14734[0][0]
#                                                                  normalization_14735[0][0]
#                                                                  normalization_14736[0][0]
#                                                                  normalization_14737[0][0]
#                                                                  normalization_14738[0][0]
#                                                                  normalization_14739[0][0]
#                                                                  normalization_14740[0][0]
#                                                                  normalization_14741[0][0]
#                                                                  normalization_14742[0][0]
#                                                                  normalization_14743[0][0]
#                                                                  normalization_14744[0][0]
#                                                                  normalization_14745[0][0]
#                                                                  normalization_14746[0][0]
#                                                                  normalization_14747[0][0]
#                                                                  normalization_14748[0][0]
#                                                                  normalization_14749[0][0]
#                                                                  normalization_14750[0][0]
#                                                                  normalization_14751[0][0]
#                                                                  normalization_14752[0][0]
#                                                                  normalization_14753[0][0]
#                                                                  normalization_14754[0][0]
#                                                                  normalization_14755[0][0]
#                                                                  normalization_14756[0][0]
#                                                                  normalization_14757[0][0]
#                                                                  normalization_14758[0][0]
#                                                                  normalization_14759[0][0]
#                                                                  normalization_14760[0][0]
#                                                                  normalization_14761[0][0]
#                                                                  normalization_14762[0][0]
#                                                                  normalization_14763[0][0]
#                                                                  normalization_14764[0][0]
#                                                                  normalization_14765[0][0]
#                                                                  normalization_14766[0][0]
#                                                                  normalization_14767[0][0]
#                                                                  normalization_14768[0][0]
#                                                                  normalization_14769[0][0]
#                                                                  normalization_14770[0][0]
#                                                                  normalization_14771[0][0]
#                                                                  normalization_14772[0][0]
#                                                                  normalization_14773[0][0]
#                                                                  normalization_14774[0][0]
#                                                                  normalization_14775[0][0]
#                                                                  normalization_14776[0][0]
#                                                                  normalization_14777[0][0]
#                                                                  normalization_14778[0][0]
#                                                                  normalization_14779[0][0]
#                                                                  normalization_14780[0][0]
#                                                                  normalization_14781[0][0]
#                                                                  normalization_14782[0][0]
#                                                                  normalization_14783[0][0]
# __________________________________________________________________________________________________
# dense_572 (Dense)               (None, 128)          11392       concatenate_167[0][0]
# __________________________________________________________________________________________________
# dense_573 (Dense)               (None, 64)           8256        dense_572[0][0]
# __________________________________________________________________________________________________
# dense_574 (Dense)               (None, 32)           2080        dense_573[0][0]
# __________________________________________________________________________________________________
# dropout_167 (Dropout)           (None, 32)           0           dense_574[0][0]
# __________________________________________________________________________________________________
# dense_575 (Dense)               (None, 1)            33          dropout_167[0][0]
# ==================================================================================================
# Total params: 22,025
# Trainable params: 21,761
# Non-trainable params: 264
# __________________________________________________________________________________________________
# None
